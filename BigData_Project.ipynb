# %% [markdown]
# # Keyword Extraction for analyzing popularity of Algorithms
#
# ### Preksha Mutha, Snehal Kenjale, Kiranmai Nallamalli, Omkaar Khanvilkar

# %%
from pyspark.sql.types import *
from pyspark.sql import SparkSession, Row
from pyspark.sql.functions import col, lit
from functools import reduce
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import matplotlib.pyplot as plt
import pandas as pd
import re
import string
from pyspark.ml.feature import CountVectorizer, MinHashLSH
from pyspark.mllib.clustering import LDA, LDAModel
from pyspark.mllib.linalg import Vector, Vectors
from pyspark.ml.linalg import Vectors
from pyspark.sql.functions import udf
from pyspark.ml.feature import HashingTF, IDF, Tokenizer
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# %% [markdown]
# #### Loading Dataset from Mongodb

# %%
spark = SparkSession \
    .builder \
    .appName("myProject") \
    .config("spark.mongodb.input.uri", "mongodb://localhost/projectDB.papers") \
    .config('spark.jars.packages','org.mongodb.spark:mongo-spark-connector_2.12:2.4.0' ) \
    .getOrCreate()
data = my_spark.read.format("com.mongodb.spark.sql.DefaultSource").load()

# %%
content_rdd = data.select("paper_text").rdd.flatMap(lambda x: x)

# %% [markdown]
# #### Data preprocessing

# %%
lowerCase_sentRDD = content_rdd.map(lambda x : x.lower())

# %%
def sent_TokenizeFunct(x):
    nltk.data.path.append("/share/apps/python/3.6.5/data/nltk")
    return nltk.sent_tokenize(x)
sentenceTokenizeRDD = lowerCase_sentRDD.map(sent_TokenizeFunct)

# %%
def word_TokenizeFunct(x):
    splitted = [word for line in x for word in line.split()]
    return splitted
wordTokenizeRDD = sentenceTokenizeRDD.map(word_TokenizeFunct)

# %%
def removeStopWordsFunct(x):
    from nltk.corpus import stopwords
    stop_words=set(stopwords.words('english'))
    filteredSentence = [w for w in x if not w in stop_words]
    return filteredSentence
stopwordRDD = wordTokenizeRDD.map(removeStopWordsFunct)

# %%
def removePunctuationsFunct(x):
    list_punct=list(string.punctuation)
    filtered = [''.join(c for c in s if c not in list_punct) for s in x] 
    filtered_space = [s for s in filtered if s] #remove empty space 
    return filtered
rmvPunctRDD = stopwordRDD.map(removePunctuationsFunct)

# %%
def rem_single_characters(lst):
    outputlst = []
    for word in lst:
        temp = re.sub('[^a-zA-Z ]+',' ', word) 
        temp=re.sub("&lt;/?.*?&gt;",' ',temp)
        temp=re.sub("(\\d|\\W)+"," ",temp)
        if(len(temp)<=3):
            outputlst.append(' ')        
        else:
            outputlst.append(temp)
    return outputlst

# %%
rem_chara_RDD = rmvPunctRDD.map(rem_single_characters)

# %%
rem_chara_RDD.take(5)

# %%
def lemmatizationFunct(x):
    lemmatizer = WordNetLemmatizer()
    finalLem = [lemmatizer.lemmatize(s) for s in x]
    return finalLem
lem_wordsRDD = rem_chara_RDD.map(lemmatizationFunct)

# %%
def joinTokensFunct(x):
    joinedTokens_list = []
    x = " ".join(x)
    return x
joinedTokens = lem_wordsRDD.map(joinTokensFunct)

# %%
def removecharacters(text):   
    text=text.strip()
    text = re.sub('\s+', ' ', text).strip()
    return text

# %%
rem_spacesRDD = joinedTokens.map(removecharacters)

# %%
rem_spacesRDD.take(5)
# Out:
# ['selforganization associative database application hisashi suzuki suguru arimoto osaka university toyonaka osaka japan abstract efficient method selforganizing associative database proposed together application robot eyesight system proposed database associate input output first half part discussion algorithm selforganization proposed aspect hardware produce style neural network latter half part applicability handwritten letter recognition autonomous mobile robot system demonstrated introduction mapping given finite infinite another finite infinite learning machine observes pair sampled randomly mean cartesian product computes estimate make small estimation error measure usually that faster decrease estimation error increase number sample better learning machine however expression performance incomplete since lack consideration candidate assumed preliminarily find good learning machine clarify conception discus type learning machine advance understanding selforganization associative database parameter type ordinary type learning machine assumes equation relating parameter indefinite namely structure equivalent define implicitly candidate subset mapping computes value parameter based observed sample call type parameter type learning machine defined well approach number sample increase alternative case however estimation error remains eternally thus problem designing learning machine return find proper structure sense hand assumed structure demanded compact possible achieve fast learning word number parameter small since parameter uniquely determined even though observed sample however demand proper contradicts compact consequently parameter type better compactness assumed structure proper better learning machine elementary conception design learning machine universality ordinary neural network suppose sufficient knowledge given though unknown case comparatively easy find proper compact structure alternative case however sometimes difficult possible solution give compactness assume almighty structure cover various combination orthogonal base infinite dimension structure neural network approximation obtained truncating finitely dimension implementation american institute physic main topic designing neural network establish desirable structure work includes developing practical procedure compute value coefficient observed sample discussion flourishing since many efficient method proposed recently even hardware unit computing coefficient parallel speedup sold anza mark odyssey nevertheless neural network always exists danger error remaining eternally estimating precisely speaking suppose combination base finite number define structure essentially word suppose located near case estimation error none negligible however distant estimation error never becomes negligible indeed many research report following situation appears complex estimation error converges value number sample increase decrease hardly even though dimension heighten property sometimes considerable defect neural network recursi type recursive type founded another methodology learning follows initial stage sample instead notation candidate equal mapping observing first sample reduced observing second sample reduced thus candidate becomes gradually small observation sample proceeds observing isamples write likelihood estimation selected hence contrarily parameter type recursive type guarantee surely approach number sample increase recursive type observes sample rewrite value correlated sample hence type architecture composed rule rewriting free memory space architecture form naturally kind database build management system data selforganizing however database differs ordinary one following sense record sample already observed computes estimation call database associative database first subject constructing associative database establish rule rewri ting purpose adap measure called dissimilari dissimilari mean mapping real whenever however necessarily defined single formul ...
#  'mean field theory layer visual cortex application artificial neural network christopher scofield center neural science physic department brown university providence rhode island nestor richmond square providence rhode island abstract single cell theory development selectivity ocular dominance visual cortex presented previously bienenstock cooper munrol extended network applicable layer visual cortex paper present mean field approximation capture fairly transparent manner qualitative many quantitative result network theory finally consider application theory artificial neural network show significant reduction architectural complexity possible single layer network mean field approximation consider single layer network ideal neuron receive signal outside layer cell within layer figure activity cell network cell vector afferent signal network receives input fiber outside cortical network matrix synapsis intralayer input cell transmitted matrix corticocortical synapsis american institute physic afferent signal figure general single layer recurrent network light circle cortical synapsis dark circle nonmodifiable corticocortical synapsis expand response cell individual term describing number cortical synapsis traversed signal arriving synapsis cell expanding response cell becomes ljk note term contains factor form factor describes first order effect cell cortical transformation signal mean field approximation consists estimating factor constant independant cell location assumption imply cell network selective pattern thus rather assumption vector constant amount assuming cell network surrounded population cell represent average possible pattern preference thus vector afferent synaptic state describing pattern preference constant independent location finally assume lateral connection strength function becomes circular matrix constan response cell becomes define spatial average cortical cell activity average number intracortical synapsis manner similar theory magnetism replaced effect individual cortical cell average effect though cortical cell replaced effective cell figure note retained order synaptic traversal signal thus focus activity layer relaxation equilibrium mean field approximation therefore write mean field asume inhibitory afferent signal network average figure single layer mean field network detailed connectivity cell network replaced single nonmodifiable synapse effective cell learning cortical network first consider evolution network according synaptic modification rule studied detail single cell elsewhere consider cortical synapsis site plasticity assume maximum simplicity modification corticocortical synapsis follows denotes spatial average cortical cell denotes time averaged activity cortical cell function discussed extensively elsewhere note describes function cell response hebbian antihebbian region lead complex nonlinear stochastic equation analyzed partially elsewhere general afferent synaptic state fixed point stable selective unstable fixed point nonselective argument generalized network mean field approximation mean field time dependent component varies average network modifiable synapsis environmental situation change slowly compared change modifiable synapsis single cell approximation write miaa cjmia mapping mica every exists corresponding mapped point satisfies original equation mean field zero theory shown every fixed point exists corresponding fixed point selectivity stability property fixed point available neuron sufficient inhibition network sufficiently large application mean field network layer visual cortex neuron primary visual cortex normal adult cat sharply tuned orientation elongated slit light activated stimulation either propertiesorientation selectivity binocularitydepend type visual environment experienced critical period early postnatal development example deprivation patterned input critical period lead loss orientation selectivity monocular deprivation result dramatic shift ocular domi ...
#  'storing covariance associative longterm potentiation depression synaptic strength hippocampus patric stanton terrence sejnowski department biophysics john hopkins university baltimore abstract modeling study memory based neural network selective enhancement depression synaptic strength required effident storage inrormation sejnowski kohonen bienenstock sejnowski tesauro tested assumption hippocampus cortical structure brain involved longterm memory brier highfrequency activation excitatory synapsis hippocampus produce increase synaptic strength known longterm potentiation bus lomo last many day known hebbian since requires simultaneous release neurotransmitter presynaptic terminal coupled postsynaptic depolarization kelso malinow miller gustatrson however mechanism persistent reduction synaptic strength could balance demonstrated studied associative interaction separate input onto dendritic tree hippocampal pyramidal cell field round lowfrequency input itselr persistently change synaptic strength either increase associative decrease strength associative longterm depression depending upon whether positively negatively correlated time second highfrequency bursting input synaptic strength hebbian antihebbian since elicited pairing presynaptic firing postsynaptic hyperpolarization sufficient block postsynaptic activity thus associative associative capable storing inrormation contained covariance separate converging hippocampal input present address depents newoscience neurology albert einstein college medicine pelham parkway south bronx tpresent address computational neurobiology laboratory salk institute diego storing covariance synaptic strength hippocampus introduction associative produced hippocampal neuroos lowfrequency weak highfrequency strong input cell simultaneously activated levy steward levy steward barrionuevo brown stimulated alone weak input longlasting effect synaptic strength however paired stimulation separate strong input sufficient produce homo synaptic pathway weak pathway associatively potentiated neural network modeling study predicted addition hebbian form plasticity synaptic strength weakened weak strong input anticorrelated sejnowski kohonen bienenstock sejnowski tesauro evidence heterosynaptic depression hippocampus found input inactive levy steward lynch weakly active levy steward stimulation strong input depression depend pattern weak input activity typically longlasting therefore searched condition stimulation hippocampal pathway rather inactivity could produce either longterm depression potentiation synaptic strength depending pattern stimulation stimulus paradigm used illustrated based finding burst stimulus optimal eliciting hippocampus larson lynch highfrequency burst sirong stimulus applied schaffer collateral axon lowfrequency weak stimulus given separate subicular input coming opposite side recording site terminating dendrite population pyramidal neuron rhythmic nature strong input burst weak input shock could either superimposed middle burst strong input phase placed symmetrically burst phase result extracellular evoked field potential recorded apical dendritic somatic layer pyramidal cell weak stimulus train first applied alone induce longlasting change strong site stimulated alone elicited homosynaptic strong pathway significantly alter amplitude response weak input weak strong input activated phase associative weak input synapsis shown synaptic excitatory postsynaptic potential epsp aepsp population action potential pike significantly enhanced least following stimulation contrast weak strong input applied phase elicited associative longterm depression weak input synapsis shown marked reduction population spike smaller decrease epsp note stimulus pattern applied input identical experiment relative stanton sejnowski phase weak strong stimulus altered stimulus pattern synaptic strength could repeatedly enhanced depressed single slice illustrated control experiment determine whether informati ...
#  'bayesian query construction neural network model gerhard paass jorg kindermann german national research center computer science sankt augustin germany paassgmdde kindermanngmdde abstract data collection costly much gained actively selecting particularly informative data point sequential bayesian decisiontheoretic framework develop query selection criterion explicitly take account intended model prediction markov chain monte carlo method necessary quantity approximated desired precision number data point grows model complexity modified bayesian model selection strategy property version criterion demonstrated numerical experiment introduction paper consider situation data collection costly example real measurement technical experiment performed situation approach query learning active data selection sequential experimental design potential benefit depending previously seen example input value query selected systematic corresponding output obtained motivation query learning random example often contain redundant information concentration nonredundant example must necessarily improve generalization performance bayesian decisiontheoretic framework derive criterion query construction criterion reflects intended prediction appropriate gerhard paass jorg kindermann loss function limit analysis selection next data point given data already sampled proposed procedure derives expected loss candidate input selects query minimal expected loss several published survey query construction method ford plutowski white sollich current approach cohn rely information matrix parameter however parameter receive equal attention regardless influence intended model pronzato walter addition estimate valid asymptotically bayesian approach advocated berger applied neural network mackay sollich saad relation maximum information gain discussed paper show using markov chain monte carlo method possible determine quantity necessary selection query approach valid small sample situation procedure precision increased additional computational effort square loss function criterion reduced variant familiar integrated mean square error plutowski white next section develop query selection criterion decisiontheoretic point view third section show criterion calculated using markov chain monte carlo method discus strategy model selection last section result experiment mlps described decisiontheoretic framework assume input vector scalar output distributed vector parameter conditional expected value deterministic function zero mean error term suppose iteratively collected observation bayesian posterior predictive distribution prior distribution consider situation based data perform action whose result depends unknown output decision severe effect others loss function measure loss true value taken action paper consider realvalued action setting temperature chemical process select knowing input according bayes principle berger follow decision rule average risk minimal risk defined dydx distribution future input assumed known square loss function conditional expectation optimal decision rule control problem loss larger specific critical point addressed weighted square loss function berger expected loss action a hy replacing predictive density weighted predictive density bayesian query construction neural network model dengx optimal decision rule average loss given input modification later derivation square loss function applied weighted square loss query sampling selection observation average risk maximally reduced together still unknown yvalue defines observation data determine risk given perform following conceptual step candidate query future data construct possible set future observation future posterior determine future posterior distribution parameter depends though actually observed future loss assuming optimal decision rule given value compute resulting loss xxpylx wpwidenux ydydw averaging integrate quantity future trial input distributed different possible future  ...
#  'neural network ensemble cross validation active learning anders krogh nordita blegdamsvej copenhagen denmark jesper vedelsby electronics institute building technical university denmark lyngby denmark abstract learning continuous valued function using neural network ensemble committee give improved accuracy reliable estimation generalization error active learning ambiguity defined variation output ensemble member averaged unlabeled data quantifies disagreement among network discussed ambiguity combination crossvalidation give reliable estimate ensemble generalization error type ensemble crossvalidation sometimes improve performance shown estimate optimal weight ensemble member using unlabeled data generalization query committee finally shown ambiguity used select training data labeled active learning scheme introduction well known combination many different predictor improve prediction neural network community ensemble neural network investigated several author instance often network ensemble trained individually prediction combined combination usually done majority classification simple averaging regression also weighted combination network author correspondence addressed email kroghlnordita anders krogh jesper vedelsby workshop last nip conference december entire session devoted ensemble neural network putting together chaired michael perrone many interesting paper given showed area getting attention combination output several network predictor useful disagree input clearly information gained million identical network also quantifying disagreement ensemble turn possible state insight rigorously ensemble used approximation realvalued function regression simple beautiful expression relates disagreement called ensemble ambiguity generalization error basis paper derive delay biasvariance tradeoff assume task learn function sample example jxij example assumed drawn randomly distribution anything following easy generalize several output variable ensemble consists network output network input called weighted ensemble average denoted like final output ensemble think weight belief network therefore constrain weight positive constraint crucial following result ambiguity input single member ensemble defined ensemble ambiguity input lwaaax lwavax simply variance weighted ensemble around weighed mean measure disagreement among network input quadratic error network ensemble respectively adding subtracting yield wafax after little algebra using weight calling weighted average individual error becomes neural network ensemble cross validation active learning formula averaged input distribution average input distribution denoted capital letter dxpxvl dxpxaax dxpxex first generalization error ambiguity respectively network generalization error ensemble find ensemble generalization error first term right weighted average generalization error individual network waea second weighted average ambiguity waaa refer ensemble ambiguity beauty equation separate generalization error term depends generalization error individual network another term contain correlation network furthermore correlation term estimated entirely unlabeled data knowledge required real function approximated term unlabeled example borrowed classification problem context mean input value target function unknown equation express tradeoff bias variance ensemble different common biasvariance relation average possible training set instead ensemble average ensemble strongly biased ambiguity small network implement similar function thus agree input even outside training therefore generalization error essentially equal weighted average generalization error individual network hand large variance ambiguity high case generalization error smaller average generalization error also equation immediately generalization error ensemble always smaller weighted average ensemble error particular uniform weight fecx noted several author crossvalidation ensemble obvious increasing ambiguity while incre ...

# %%
wordsRDD = rem_spacesRDD.map(lambda x : x).flatMap(lambda word: word.split(" "))

# %%
wordsRDD.take(5)
# Out:
# ['selforganization', 'associative', 'database', 'application', 'hisashi']

# %%
wordcounts = rem_spacesRDD.map(lambda x : x).flatMap(lambda line: line.split(" ")) \
             .map(lambda word: (word, 1)) \
             .reduceByKey(lambda a, b: a + b)

# %%
wordcounts.take(5)
# Out:
# [('selforganization', 298),
#  ('associative', 1320),
#  ('database', 3963),
#  ('hisashi', 25),
#  ('university', 13566)]

# %%
sorted_words = wordcounts.takeOrdered(len(wordcounts.collect()),key=lambda x: -x[1])

# %%
plot_word_list = sorted_words[:25]

# %%
plot_word_list
# Out:
# [('model', 150984),
#  ('algorithm', 115837),
#  ('learning', 104005),
#  ('function', 96738),
#  ('data', 91776),
#  ('network', 76318),
#  ('method', 73024),
#  ('problem', 72250),
#  ('using', 67961),
#  ('result', 64272),
#  ('time', 60113),
#  ('distribution', 59938),
#  ('number', 57145),
#  ('figure', 54992),
#  ('matrix', 51319),
#  ('parameter', 49976),
#  ('value', 49575),
#  ('feature', 49096),
#  ('image', 48323),
#  ('also', 46775),
#  ('training', 46156),
#  ('given', 45829),
#  ('used', 45541),
#  ('show', 44910),
#  ('neural', 44543)]

# %%
# removing additional unnecesary words
new_words = ["using", "show", "result", "large", "also", "iv", "one", "two", "new", "previously", "shown"]

# %%
filteredWords = [word for word in sorted_words if word not in new_words]

# %%
from pyspark.sql import *

# %%
finaldf = rem_spacesRDD.map(lambda x : [x])

# %%
finaldf.take(5)
# Out:
# [['selforganization associative database application hisashi suzuki suguru arimoto osaka university toyonaka osaka japan abstract efficient method selforganizing associative database proposed together application robot eyesight system proposed database associate input output first half part discussion algorithm selforganization proposed aspect hardware produce style neural network latter half part applicability handwritten letter recognition autonomous mobile robot system demonstrated introduction mapping given finite infinite another finite infinite learning machine observes pair sampled randomly mean cartesian product computes estimate make small estimation error measure usually that faster decrease estimation error increase number sample better learning machine however expression performance incomplete since lack consideration candidate assumed preliminarily find good learning machine clarify conception discus type learning machine advance understanding selforganization associative database parameter type ordinary type learning machine assumes equation relating parameter indefinite namely structure equivalent define implicitly candidate subset mapping computes value parameter based observed sample call type parameter type learning machine defined well approach number sample increase alternative case however estimation error remains eternally thus problem designing learning machine return find proper structure sense hand assumed structure demanded compact possible achieve fast learning word number parameter small since parameter uniquely determined even though observed sample however demand proper contradicts compact consequently parameter type better compactness assumed structure proper better learning machine elementary conception design learning machine universality ordinary neural network suppose sufficient knowledge given though unknown case comparatively easy find proper compact structure alternative case however sometimes difficult possible solution give compactness assume almighty structure cover various combination orthogonal base infinite dimension structure neural network approximation obtained truncating finitely dimension implementation american institute physic main topic designing neural network establish desirable structure work includes developing practical procedure compute value coefficient observed sample discussion flourishing since many efficient method proposed recently even hardware unit computing coefficient parallel speedup sold anza mark odyssey nevertheless neural network always exists danger error remaining eternally estimating precisely speaking suppose combination base finite number define structure essentially word suppose located near case estimation error none negligible however distant estimation error never becomes negligible indeed many research report following situation appears complex estimation error converges value number sample increase decrease hardly even though dimension heighten property sometimes considerable defect neural network recursi type recursive type founded another methodology learning follows initial stage sample instead notation candidate equal mapping observing first sample reduced observing second sample reduced thus candidate becomes gradually small observation sample proceeds observing isamples write likelihood estimation selected hence contrarily parameter type recursive type guarantee surely approach number sample increase recursive type observes sample rewrite value correlated sample hence type architecture composed rule rewriting free memory space architecture form naturally kind database build management system data selforganizing however database differs ordinary one following sense record sample already observed computes estimation call database associative database first subject constructing associative database establish rule rewri ting purpose adap measure called dissimilari dissimilari mean mapping real whenever however necessarily defined single formu ...
#  ['mean field theory layer visual cortex application artificial neural network christopher scofield center neural science physic department brown university providence rhode island nestor richmond square providence rhode island abstract single cell theory development selectivity ocular dominance visual cortex presented previously bienenstock cooper munrol extended network applicable layer visual cortex paper present mean field approximation capture fairly transparent manner qualitative many quantitative result network theory finally consider application theory artificial neural network show significant reduction architectural complexity possible single layer network mean field approximation consider single layer network ideal neuron receive signal outside layer cell within layer figure activity cell network cell vector afferent signal network receives input fiber outside cortical network matrix synapsis intralayer input cell transmitted matrix corticocortical synapsis american institute physic afferent signal figure general single layer recurrent network light circle cortical synapsis dark circle nonmodifiable corticocortical synapsis expand response cell individual term describing number cortical synapsis traversed signal arriving synapsis cell expanding response cell becomes ljk note term contains factor form factor describes first order effect cell cortical transformation signal mean field approximation consists estimating factor constant independant cell location assumption imply cell network selective pattern thus rather assumption vector constant amount assuming cell network surrounded population cell represent average possible pattern preference thus vector afferent synaptic state describing pattern preference constant independent location finally assume lateral connection strength function becomes circular matrix constan response cell becomes define spatial average cortical cell activity average number intracortical synapsis manner similar theory magnetism replaced effect individual cortical cell average effect though cortical cell replaced effective cell figure note retained order synaptic traversal signal thus focus activity layer relaxation equilibrium mean field approximation therefore write mean field asume inhibitory afferent signal network average figure single layer mean field network detailed connectivity cell network replaced single nonmodifiable synapse effective cell learning cortical network first consider evolution network according synaptic modification rule studied detail single cell elsewhere consider cortical synapsis site plasticity assume maximum simplicity modification corticocortical synapsis follows denotes spatial average cortical cell denotes time averaged activity cortical cell function discussed extensively elsewhere note describes function cell response hebbian antihebbian region lead complex nonlinear stochastic equation analyzed partially elsewhere general afferent synaptic state fixed point stable selective unstable fixed point nonselective argument generalized network mean field approximation mean field time dependent component varies average network modifiable synapsis environmental situation change slowly compared change modifiable synapsis single cell approximation write miaa cjmia mapping mica every exists corresponding mapped point satisfies original equation mean field zero theory shown every fixed point exists corresponding fixed point selectivity stability property fixed point available neuron sufficient inhibition network sufficiently large application mean field network layer visual cortex neuron primary visual cortex normal adult cat sharply tuned orientation elongated slit light activated stimulation either propertiesorientation selectivity binocularitydepend type visual environment experienced critical period early postnatal development example deprivation patterned input critical period lead loss orientation selectivity monocular deprivation result dramatic shift ocular dom ...
#  ['storing covariance associative longterm potentiation depression synaptic strength hippocampus patric stanton terrence sejnowski department biophysics john hopkins university baltimore abstract modeling study memory based neural network selective enhancement depression synaptic strength required effident storage inrormation sejnowski kohonen bienenstock sejnowski tesauro tested assumption hippocampus cortical structure brain involved longterm memory brier highfrequency activation excitatory synapsis hippocampus produce increase synaptic strength known longterm potentiation bus lomo last many day known hebbian since requires simultaneous release neurotransmitter presynaptic terminal coupled postsynaptic depolarization kelso malinow miller gustatrson however mechanism persistent reduction synaptic strength could balance demonstrated studied associative interaction separate input onto dendritic tree hippocampal pyramidal cell field round lowfrequency input itselr persistently change synaptic strength either increase associative decrease strength associative longterm depression depending upon whether positively negatively correlated time second highfrequency bursting input synaptic strength hebbian antihebbian since elicited pairing presynaptic firing postsynaptic hyperpolarization sufficient block postsynaptic activity thus associative associative capable storing inrormation contained covariance separate converging hippocampal input present address depents newoscience neurology albert einstein college medicine pelham parkway south bronx tpresent address computational neurobiology laboratory salk institute diego storing covariance synaptic strength hippocampus introduction associative produced hippocampal neuroos lowfrequency weak highfrequency strong input cell simultaneously activated levy steward levy steward barrionuevo brown stimulated alone weak input longlasting effect synaptic strength however paired stimulation separate strong input sufficient produce homo synaptic pathway weak pathway associatively potentiated neural network modeling study predicted addition hebbian form plasticity synaptic strength weakened weak strong input anticorrelated sejnowski kohonen bienenstock sejnowski tesauro evidence heterosynaptic depression hippocampus found input inactive levy steward lynch weakly active levy steward stimulation strong input depression depend pattern weak input activity typically longlasting therefore searched condition stimulation hippocampal pathway rather inactivity could produce either longterm depression potentiation synaptic strength depending pattern stimulation stimulus paradigm used illustrated based finding burst stimulus optimal eliciting hippocampus larson lynch highfrequency burst sirong stimulus applied schaffer collateral axon lowfrequency weak stimulus given separate subicular input coming opposite side recording site terminating dendrite population pyramidal neuron rhythmic nature strong input burst weak input shock could either superimposed middle burst strong input phase placed symmetrically burst phase result extracellular evoked field potential recorded apical dendritic somatic layer pyramidal cell weak stimulus train first applied alone induce longlasting change strong site stimulated alone elicited homosynaptic strong pathway significantly alter amplitude response weak input weak strong input activated phase associative weak input synapsis shown synaptic excitatory postsynaptic potential epsp aepsp population action potential pike significantly enhanced least following stimulation contrast weak strong input applied phase elicited associative longterm depression weak input synapsis shown marked reduction population spike smaller decrease epsp note stimulus pattern applied input identical experiment relative stanton sejnowski phase weak strong stimulus altered stimulus pattern synaptic strength could repeatedly enhanced depressed single slice illustrated control experiment determine whether informat ...
#  ['bayesian query construction neural network model gerhard paass jorg kindermann german national research center computer science sankt augustin germany paassgmdde kindermanngmdde abstract data collection costly much gained actively selecting particularly informative data point sequential bayesian decisiontheoretic framework develop query selection criterion explicitly take account intended model prediction markov chain monte carlo method necessary quantity approximated desired precision number data point grows model complexity modified bayesian model selection strategy property version criterion demonstrated numerical experiment introduction paper consider situation data collection costly example real measurement technical experiment performed situation approach query learning active data selection sequential experimental design potential benefit depending previously seen example input value query selected systematic corresponding output obtained motivation query learning random example often contain redundant information concentration nonredundant example must necessarily improve generalization performance bayesian decisiontheoretic framework derive criterion query construction criterion reflects intended prediction appropriate gerhard paass jorg kindermann loss function limit analysis selection next data point given data already sampled proposed procedure derives expected loss candidate input selects query minimal expected loss several published survey query construction method ford plutowski white sollich current approach cohn rely information matrix parameter however parameter receive equal attention regardless influence intended model pronzato walter addition estimate valid asymptotically bayesian approach advocated berger applied neural network mackay sollich saad relation maximum information gain discussed paper show using markov chain monte carlo method possible determine quantity necessary selection query approach valid small sample situation procedure precision increased additional computational effort square loss function criterion reduced variant familiar integrated mean square error plutowski white next section develop query selection criterion decisiontheoretic point view third section show criterion calculated using markov chain monte carlo method discus strategy model selection last section result experiment mlps described decisiontheoretic framework assume input vector scalar output distributed vector parameter conditional expected value deterministic function zero mean error term suppose iteratively collected observation bayesian posterior predictive distribution prior distribution consider situation based data perform action whose result depends unknown output decision severe effect others loss function measure loss true value taken action paper consider realvalued action setting temperature chemical process select knowing input according bayes principle berger follow decision rule average risk minimal risk defined dydx distribution future input assumed known square loss function conditional expectation optimal decision rule control problem loss larger specific critical point addressed weighted square loss function berger expected loss action a hy replacing predictive density weighted predictive density bayesian query construction neural network model dengx optimal decision rule average loss given input modification later derivation square loss function applied weighted square loss query sampling selection observation average risk maximally reduced together still unknown yvalue defines observation data determine risk given perform following conceptual step candidate query future data construct possible set future observation future posterior determine future posterior distribution parameter depends though actually observed future loss assuming optimal decision rule given value compute resulting loss xxpylx wpwidenux ydydw averaging integrate quantity future trial input distributed different possible future ...
#  ['neural network ensemble cross validation active learning anders krogh nordita blegdamsvej copenhagen denmark jesper vedelsby electronics institute building technical university denmark lyngby denmark abstract learning continuous valued function using neural network ensemble committee give improved accuracy reliable estimation generalization error active learning ambiguity defined variation output ensemble member averaged unlabeled data quantifies disagreement among network discussed ambiguity combination crossvalidation give reliable estimate ensemble generalization error type ensemble crossvalidation sometimes improve performance shown estimate optimal weight ensemble member using unlabeled data generalization query committee finally shown ambiguity used select training data labeled active learning scheme introduction well known combination many different predictor improve prediction neural network community ensemble neural network investigated several author instance often network ensemble trained individually prediction combined combination usually done majority classification simple averaging regression also weighted combination network author correspondence addressed email kroghlnordita anders krogh jesper vedelsby workshop last nip conference december entire session devoted ensemble neural network putting together chaired michael perrone many interesting paper given showed area getting attention combination output several network predictor useful disagree input clearly information gained million identical network also quantifying disagreement ensemble turn possible state insight rigorously ensemble used approximation realvalued function regression simple beautiful expression relates disagreement called ensemble ambiguity generalization error basis paper derive delay biasvariance tradeoff assume task learn function sample example jxij example assumed drawn randomly distribution anything following easy generalize several output variable ensemble consists network output network input called weighted ensemble average denoted like final output ensemble think weight belief network therefore constrain weight positive constraint crucial following result ambiguity input single member ensemble defined ensemble ambiguity input lwaaax lwavax simply variance weighted ensemble around weighed mean measure disagreement among network input quadratic error network ensemble respectively adding subtracting yield wafax after little algebra using weight calling weighted average individual error becomes neural network ensemble cross validation active learning formula averaged input distribution average input distribution denoted capital letter dxpxvl dxpxaax dxpxex first generalization error ambiguity respectively network generalization error ensemble find ensemble generalization error first term right weighted average generalization error individual network waea second weighted average ambiguity waaa refer ensemble ambiguity beauty equation separate generalization error term depends generalization error individual network another term contain correlation network furthermore correlation term estimated entirely unlabeled data knowledge required real function approximated term unlabeled example borrowed classification problem context mean input value target function unknown equation express tradeoff bias variance ensemble different common biasvariance relation average possible training set instead ensemble average ensemble strongly biased ambiguity small network implement similar function thus agree input even outside training therefore generalization error essentially equal weighted average generalization error individual network hand large variance ambiguity high case generalization error smaller average generalization error also equation immediately generalization error ensemble always smaller weighted average ensemble error particular uniform weight fecx noted several author crossvalidation ensemble obvious increasing ambiguity while incr ...

# %%
finaldf1 = sqlContext.createDataFrame(finaldf,['text'])

# %%
finaldf1.show()
# Out:
# +--------------------+
# |                text|
# +--------------------+
# |selforganization ...|
# |mean field theory...|
# |storing covarianc...|
# |bayesian query co...|
# |neural network en...|
# |sing neural insta...|
# |plasticitymediate...|
# |iceg morphology c...|
# |realtime control ...|
# |realtime control ...|
# |learning play gam...|
# |multidimensional ...|
# |experimental comp...|
# |training multilay...|
# |interference lear...|
# |active learning s...|
# |rapid graphbased ...|
# |ocular dominance ...|
# |associative decor...|
# |connectionist tec...|
# +--------------------+
# only showing top 20 rows

# %%
from pyspark.sql import functions as F

# %%
concat_list = udf(lambda lst: " ".join(lst), StringType())

df1 = finaldf1.withColumn("combined", concat_list("text"))

# %%
finaldf2 = finaldf1.withColumn("words", F.split(finaldf1['text'], ' '))

# %%
finaldf2.show()
# Out:
# +--------------------+--------------------+
# |                text|               words|
# +--------------------+--------------------+
# |selforganization ...|[selforganization...|
# |mean field theory...|[mean, field, the...|
# |storing covarianc...|[storing, covaria...|
# |bayesian query co...|[bayesian, query,...|
# |neural network en...|[neural, network,...|
# |sing neural insta...|[sing, neural, in...|
# |plasticitymediate...|[plasticitymediat...|
# |iceg morphology c...|[iceg, morphology...|
# |realtime control ...|[realtime, contro...|
# |realtime control ...|[realtime, contro...|
# |learning play gam...|[learning, play, ...|
# |multidimensional ...|[multidimensional...|
# |experimental comp...|[experimental, co...|
# |training multilay...|[training, multil...|
# |interference lear...|[interference, le...|
# |active learning s...|[active, learning...|
# |rapid graphbased ...|[rapid, graphbase...|
# |ocular dominance ...|[ocular, dominanc...|
# |associative decor...|[associative, dec...|
# |connectionist tec...|[connectionist, t...|
# +--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# #### Models

# %%
from pyspark.ml.feature import NGram

# %%
bigram = NGram(n=2, inputCol="words", outputCol="bigrams")
bigramDataFrame = bigram.transform(finaldf2)

# %%
topbigrams = bigramDataFrame.withColumn('topbigrams', F.explode(F.col('bigrams')))\
    .groupBy('topbigrams')\
    .count()\
    .sort('count', ascending=False)

# %%
topbigrams.select('topbigrams').show(10)
# Out:
# +--------------------+
# |          topbigrams|
# +--------------------+
# |      neural network|
# |    machine learning|
# |information proce...|
# |  neural information|
# |   processing system|
# |  learning algorithm|
# |international con...|
# |         figure show|
# |         lower bound|
# |      advance neural|
# +--------------------+
# only showing top 10 rows

# %%
trigram = NGram(n=3, inputCol="words", outputCol="trigrams")
trigramDataFrame = trigram.transform(bigramDataFrame)

# %%
topwords = trigramDataFrame.withColumn('word', F.explode(F.col('trigrams')))\
    .groupBy('word')\
    .count()\
    .sort('count', ascending=False)

# %%
topwords.select('word').show(10)
# Out:
# +--------------------+
# |                word|
# +--------------------+
# |neural informatio...|
# |information proce...|
# |advance neural in...|
# |arxiv preprint arxiv|
# |conference machin...|
# |international con...|
# |machine learning ...|
# |journal machine l...|
# |processing system...|
# |proceeding intern...|
# +--------------------+
# only showing top 10 rows

# %%
topwords.write.csv('topwords_trigrams1.csv')

# %%
list_trigrams = topwords.select("word").rdd.flatMap(lambda x: x)

# %%
list_trigrams.take(5)
# Out:
# ['neural information processing',
#  'information processing system',
#  'advance neural information',
#  'arxiv preprint arxiv',
#  'conference machine learning']

# %%
df = pd.read_csv("trigrams_list.csv")

# %%
tri_lsit = df["neural information processing"]

# %%
tri = tri_lsit.tolist()

# %%
res2 = [k for k in tri if 'network' in k]

# %%
res3 = [k for k in res2 if 'learning' not in res2]

# %%
res = [k for k in tri if 'algorithm' in k]

# %%
res2
# Out:
# ['recurrent neural network',
#  'convolutional neural network',
#  'deep neural network',
#  'artificial neural network',
#  'neural network model',
#  'feedforward neural network',
#  'generative adversarial network',
#  'network advance neural',
#  'network arxiv preprint',
#  'neural network architecture',
#  'learning neural network',
#  'using neural network',
#  'deep belief network',
#  'transaction neural network',
#  'conference neural network',
#  'training neural network',
#  'deep convolutional network',
#  'neural network arxiv',
#  'neural network advance',
#  'neural network neural',
#  'neural network learning',
#  'dynamic bayesian network',
#  'basis function network',
#  'neural network nip',
#  'network neural computation',
#  'neural network ieee',
#  'model neural network',
#  'network hidden unit',
#  'network machine learning',
#  'network hidden layer',
#  'neural network trained',
#  'learning bayesian network',
#  'multilayer neural network',
#  'neural network hidden',
#  'network computation neural',
#  'sigmoid belief network',
#  'neural network proceeding',
#  'neural network using',
#  'network neural network',
#  'neural network training',
#  'trans neural network',
#  'network ieee transaction',
#  'neural network classifier',
#  'network spiking neuron',
#  'neural network used',
#  'neural network approach',
#  'neural network based',
#  'adversarial network arxiv',
#  'network proceeding international',
#  'network trained using',
#  'layer neural network',
#  'network largescale image',
#  'convolutional network largescale',
#  'function neural network',
#  'recursive neural network',
#  'bayesian neural network',
#  'algorithm neural network',
#  'neural network proc',
#  'neural network science',
#  'network international conference',
#  'bayesian network structure',
#  'data neural network',
#  'training deep network',
#  'deep network training',
#  'network technical report',
#  'theory neural network',
#  'neural network page',
#  'neural network image',
#  'markov logic network',
#  'accelerating deep network',
#  'network training reducing',
#  'neural network machine',
#  'application neural network',
#  'neural network cnns',
#  'neural network pattern',
#  'hopfield neural network',
#  'system network plausible',
#  'analog neural network',
#  'network plausible inference',
#  'intelligent system network',
#  'neural network physical',
#  'timedelay neural network',
#  'attractor neural network',
#  'maxmargin markov network',
#  'pascal network excellence',
#  'stochastic neural network',
#  'vlsi neural network',
#  'network shown figure',
#  'recognition neural network',
#  'neural network weight',
#  'neural network input',
#  'network corr abs',
#  'social network analysis',
#  'network pattern recognition',
#  'fully connected network',
#  'neural network dynamic',
#  'neural network international',
#  'neural network learn',
#  'fully convolutional network',
#  'network signal processing',
#  'method neural network',
#  'delay neural network',
#  'hidden unit network',
#  'neural network implementation',
#  'neural network signal',
#  'property neural network',
#  'neural network algorithm',
#  'neural network application',
#  'neural network icml',
#  'neural network rnns',
#  'network physical system',
#  'conf neural network',
#  'adversarial network gans',
#  'train neural network',
#  'spiking neural network',
#  'neural network applied',
#  'multilayer feedforward network',
#  'selforganizing neural network',
#  'learning belief network',
#  'output neural network',
#  'feed forward network',
#  'weight neural network',
#  'performance neural network',
#  'network nip page',
#  'problem neural network',
#  'neural network chip',
#  'network artificial intelligence',
#  'simple recurrent network',
#  'trained neural network',
#  'spatial transformer network',
#  'neural network control',
#  'neural network trick',
#  'neural network layer',
#  'network trick trade',
#  'neural network figure',
#  'neural network parameter',
#  'neural network diego',
#  'based neural network',
#  'hidden layer network',
#  'neural network simulation',
#  'neural network overfitting',
#  'neural network acoustic',
#  'bishop neural network',
#  'implementation neural network',
#  'neural network computing',
#  'system neural network',
#  'neural network output',
#  'deep network nip',
#  'network neural information',
#  'used neural network',
#  'input neural network',
#  'network structure learning',
#  'network input unit',
#  'neural network also',
#  'neural network journal',
#  'network excellence ist',
#  'prevent neural network',
#  'neural network icann',
#  'deep residual network',
#  'network semantic segmentation',
#  'neural network thesis',
#  'network ieee trans',
#  'linear neural network',
#  'generalization neural network',
#  'neural network volume',
#  'editor neural network',
#  'community pascal network',
#  'improving neural network',
#  'unsupervised neural network',
#  'mixture density network',
#  'standard neural network',
#  'biological neural network',
#  'neural network policy',
#  'parameter neural network',
#  'neural network language',
#  'neural network ijcnn',
#  'network physical review',
#  'bayesian belief network',
#  'probabilistic neural network',
#  'convolutional network arxiv',
#  'convolutional kernel network',
#  'network journal machine',
#  'learning markov network',
#  'layered neural network',
#  'network learning algorithm',
#  'gene regulatory network',
#  'introduction neural network',
#  'neural network system',
#  'neural network cvpr',
#  'neural network learns',
#  'neural network shown',
#  'twolayer neural network',
#  'neural network method',
#  'network preventing coadaptation',
#  'neural network function',
#  'online social network',
#  'social network proceeding',
#  'neural network preventing',
#  'architecture neural network',
#  'convolutional network semantic',
#  'neural network network',
#  'neural network show',
#  'neural network cambridge',
#  'representation deep network',
#  'neural network technical',
#  'neural network however',
#  'markov network nip',
#  'neural network controller',
#  'neural network ensemble',
#  'layer deep network',
#  'simple neural network',
#  'class neural network',
#  'neural network perform',
#  'used train network',
#  'network proceeding ieee',
#  'influence social network',
#  'neural network structure',
#  'network volume page',
#  'using convolutional network',
#  'neural network tree',
#  'figure network architecture',
#  'dynamic neural network',
#  'belief network artificial',
#  'community structure network',
#  'region proposal network',
#  'network image generation',
#  'neural network result',
#  'type neural network',
#  'neural network prediction',
#  'network language model',
#  'network proceeding national',
#  'bayesian network proceeding',
#  'connected neural network',
#  'neural network whose',
#  'inference neural network',
#  'vapnik supportvector network',
#  'neural network take',
#  'graph neural network',
#  'network figure show',
#  'approximators neural network',
#  'densely connected network',
#  'network tree search',
#  'neural network literature',
#  'network cambridge university',
#  'neural network deep',
#  'approach neural network',
#  'network image classification',
#  'neural network first',
#  'recognition backpropagation network',
#  'competitive neural network',
#  'network multitask learning',
#  'network approximation learning',
#  'neural network phys',
#  'supportvector network machine',
#  'network complex system',
#  'classification neural network',
#  'single layer network',
#  'neural network section',
#  'coursera neural network',
#  'neural network dnns',
#  'neural network regression',
#  'neural network time',
#  'model bayesian network',
#  'neural network could',
#  'control neural network',
#  'backpropagation neural network',
#  'network visual recognition',
#  'network overfitting journal',
#  'structure neural network',
#  'neural network linear',
#  'network binary weight',
#  'network flow problem',
#  'network take input',
#  'sigmoidal neural network',
#  'result neural network',
#  'fast learning network',
#  'large neural network',
#  'network learning theoretical',
#  'neural network springer',
#  'power neural network',
#  'network support vector',
#  'neural network speech',
#  'network single hidden',
#  'back propagation network',
#  'dynamic filter network',
#  'nonlinear neural network',
#  'network scalable unsupervised',
#  'network fully connected',
#  'neural network press',
#  'recurrent convolutional network',
#  'belief network scalable',
#  'unit neural network',
#  'network input hidden',
#  'inference bayesian network',
#  'neural network statistical',
#  'bartlett neural network',
#  'network universal approximators',
#  'neural network multitask',
#  'different neural network',
#  'generative stochastic network',
#  'neural network research',
#  'neural network example',
#  'neural network visual',
#  'neural network design',
#  'network trained backpropagation',
#  'information diffusion network',
#  'markov network structure',
#  'deep network advance',
#  'regularization neural network',
#  'neural network simple',
#  'network proc nip',
#  'adaptive neural network',
#  'bengio maxout network',
#  'memory neural network',
#  'neural network size',
#  'neural network problem',
#  'field neural network',
#  'implemented neural network',
#  'processing neural network',
#  'maximization social network',
#  'network unsupervised feature',
#  'neural network particular',
#  'example neural network',
#  'network hidden markov',
#  'treewidth bayesian network',
#  'output unit network',
#  'network architecture neural',
#  'neural network described',
#  'convolutional network visual',
#  'adversarial network iclr',
#  'neural network modeling',
#  'analysis neural network',
#  'bayesian network model',
#  'complexity neural network',
#  'machine neural network',
#  'network proc ieee',
#  'associative memory network',
#  'deep network local',
#  'sparse refire network',
#  'neural network given',
#  'recurrent network neural',
#  'chordal markov network',
#  'optimal bayesian network',
#  'applied neural network',
#  'kary neural network',
#  'network acoustic modeling',
#  'network integrateandfire neuron',
#  'knowledge neural network',
#  'neural tensor network',
#  'neural network complex',
#  'workshop neural network',
#  'neural network corr',
#  'neural network iclr',
#  'distribution neural network',
#  'neural network study',
#  'network locallytuned processing',
#  'network local denoising',
#  'relational markov network',
#  'shown figure network',
#  'network european conference',
#  'neural network classification',
#  'echo state network',
#  'network input output',
#  'locally connected network',
#  'proposed neural network',
#  'abstract neural network',
#  'distributed deep network',
#  'singlelayer network unsupervised',
#  'neural network appear',
#  'design neural network',
#  'using deep network',
#  'figure neural network',
#  'neural network approximate',
#  'neural network aistats',
#  'neural network community',
#  'neural network washington',
#  'network phys lett',
#  'network time series',
#  'knowledgebased neural network',
#  'pyramid adversarial network',
#  'network linear threshold',
#  'dynamic recurrent network',
#  'moment matching network',
#  'node neural network',
#  'network architecture used',
#  'analysis singlelayer network',
#  'learning ladder network',
#  'invariance adaptive network',
#  'neural network paper',
#  'random neural network',
#  'feedforward network universal',
#  'neural network work',
#  'ieee neural network',
#  'figure show network',
#  'neural network predict',
#  'network output unit',
#  'neural network stochastic',
#  'layer feedforward network',
#  'neural network provide',
#  'learning network locallytuned',
#  'wireless sensor network',
#  'support vector network',
#  'network principal component',
#  'bayesian network learning',
#  'neural network make',
#  'neural network theory',
#  'network journal artificial',
#  'bayesian network using',
#  'neural network object',
#  'neural network technique',
#  'network object recognition',
#  'neural network without',
#  'neural network often',
#  'neural network structured',
#  'neural network neuron',
#  'neural network single',
#  'neural network principal',
#  'neuron neural network',
#  'randomly initialized network',
#  'neural network recently',
#  'many neural network',
#  'neural network large',
#  'network biasvariance dilemma',
#  'show neural network',
#  'representation neural network',
#  'using bayesian network',
#  'train deep network',
#  'network trained predict',
#  'deep network trained',
#  'neural network introduction',
#  'voc result httpwwwpascalnetworkorgchallengesvocvoc',
#  'first layer network',
#  'neural network biasvariance',
#  'information neural network',
#  'pattern presented network',
#  'adaptation neural network',
#  'neural network simulator',
#  'network speech recognition',
#  'neural network nonlinear',
#  'neural network feature',
#  'backpropagation network neural',
#  'network learning system',
#  'ground markov network',
#  'neural network random',
#  'regression neural network',
#  'order recurrent network',
#  'neural network kernel',
#  'bayesian network proc',
#  'selforganization perceptual network',
#  'layer network trained',
#  'neural network proposed',
#  'belief network neural',
#  'network special case',
#  'step social network',
#  'network architecture network',
#  'time bayesian network',
#  'neural network representation',
#  'learning algorithm network',
#  'error propagation network',
#  'network international journal',
#  'neural network able',
#  'adversarial network nip',
#  'network architecture training',
#  'firing rate network',
#  'optimization neural network',
#  'shortterm memory network',
#  'network model network',
#  'neural network conference',
#  'neural network sequence',
#  'different network architecture',
#  'vector network machine',
#  'robust neural network',
#  'deep network arxiv',
#  'belief network journal',
#  'network recurrent network',
#  'doursat neural network',
#  'encoding model network',
#  'result httpwwwpascalnetworkorgchallengesvocvoc workshopindexhtml',
#  'neural network number',
#  'network comput neural',
#  'fullyconnected neural network',
#  'network using dropconnect',
#  'bound neural network',
#  'neural network gaussian',
#  'network expert system',
#  'continuoustime diffusion network',
#  'network icml page',
#  'case neural network',
#  'recurrent network grammatical',
#  'neural network local',
#  'neural networkbased face',
#  'neural network general',
#  'lateral inhibition network',
#  'neural network implement',
#  'neural network pruning',
#  'neural network well',
#  'recurrent network architecture',
#  'network large number',
#  'network ieee international',
#  'neural network since',
#  'learned neural network',
#  'number weight network',
#  'kernel neural network',
#  'network proceeding sigkdd',
#  'network gradient descent',
#  'network model neural',
#  'network generative model',
#  'neural network adaptive',
#  'neural network thus',
#  'shallow neural network',
#  'network combination knowledge',
#  'complex neural network',
#  'neural network order',
#  'neural network task',
#  'belief network proceeding',
#  'bayesian network journal',
#  'graph convolutional network',
#  'network architecture shown',
#  'markov network using',
#  'network input vector',
#  'recurrent network model',
#  'depth neural network',
#  'neural network experiment',
#  'model social network',
#  'supervised neural network',
#  'network training algorithm',
#  'network size weight',
#  'network input layer',
#  'inverse graphic network',
#  'bayesian network combination',
#  'neural network capable',
#  'network able learn',
#  'pairwise markov network',
#  'behavior neural network',
#  'neural network support',
#  'neural network process',
#  'neural network estimate',
#  'networkbased face detection',
#  'dynamic social network',
#  'forward neural network',
#  'network gating network',
#  'neural network recurrent',
#  'training data network',
#  'piecewise polynomial network',
#  'uncertainty neural network',
#  'size neural network',
#  'neural network approximation',
#  'wide residual network',
#  'train network using',
#  'characteristic neural network',
#  'network activation function',
#  'neural network optimization',
#  'network proceeding conference',
#  'fuzzy neural network',
#  'network model ieee',
#  'training recurrent network',
#  'ability neural network',
#  'training convolutional network',
#  'model network computation',
#  'neural network recognize',
#  'social network data',
#  'network sequence modeling',
#  'neural network would',
#  'logic network machine',
#  'network acoustic model',
#  'network thesis university',
#  'network icann page',
#  'minimum neural network',
#  'deep network learning',
#  'neural network case',
#  'network moody hanson',
#  'network reinforcement learning',
#  'neural network produce',
#  'technique neural network',
#  'neural network analysis',
#  'neural network acknowledgement',
#  'structured output network',
#  'haykin neural network',
#  'ensemble neural network',
#  'poggio girosi network',
#  'surface multilayer network',
#  'sequence neural network',
#  'neural network submitted',
#  'since neural network',
#  'mapping neural network',
#  'optimizing neural network',
#  'neural network multilayer',
#  'single neural network',
#  'understanding neural network',
#  'flow anticipating network',
#  'network residual network',
#  'network computer vision',
#  'understanding convolutional network',
#  'network graphical model',
#  'theory network approximation',
#  'network pruning trained',
#  'neural network many',
#  'neural network solution',
#  'endtoend memory network',
#  'neural network information',
#  'network proc icml',
#  'keeping neural network',
#  'neural network binary',
#  'mead winnertakeall network',
#  'neural network designed',
#  'convolutional network image',
#  'network trained different',
#  'neural network bayesian',
#  'task neural network',
#  'higherorder neural network',
#  'present neural network',
#  'natural image network',
#  'form neural network',
#  'neural network called',
#  'three layer network',
#  'network number hidden',
#  'context neural network',
#  'neural network us',
#  'convex neural network',
#  'us neural network',
#  'neural network springerverlag',
#  'describe neural network',
#  'network latent variable',
#  'neural network graph',
#  'winnertakeall network complexity',
#  'network model based',
#  'deep autoregressive network',
#  'neural network typically',
#  'adversarial network corr',
#  'problem social network',
#  'neural network defined',
#  'neural network reference',
#  'feature neural network',
#  'neural network framework',
#  'capacity neural network',
#  'network excitatory inhibitory',
#  'neural network continuous',
#  'figure bayesian network',
#  'neural network generate',
#  'neural network several',
#  'neural network conventional',
#  'learning recurrent network',
#  'neural network natural',
#  'neural network compute',
#  'network radial basis',
#  'network atari game',
#  'neural network bound',
#  'number neuron network',
#  'neural network need',
#  'deep network atari',
#  'congress neural network',
#  'network model mechanism',
#  'sigmoidal belief network',
#  'selection neural network',
#  'unit network trained',
#  'error rate network',
#  'network based model',
#  'neural network class',
#  'network bounded treewidth',
#  'dual path network',
#  'input layer network',
#  'network time delay',
#  'neural network online',
#  'girosi network approximation',
#  'network relu activation',
#  'neural network mapping',
#  'deep sumproduct network',
#  'dynamic memory network',
#  'improve neural network',
#  'training connectionist network',
#  'conditional adversarial network',
#  'feedforward network trained',
#  'modular neural network',
#  'secondorder recurrent network',
#  'rectifier neural network',
#  'network proc conf',
#  'predictive neural network',
#  'variable bayesian network',
#  'propose neural network',
#  'network arxiv eprints',
#  'quantum neural network',
#  'neural network map',
#  'belief network deep',
#  'explanationbased neural network',
#  'network input node',
#  'neural network table',
#  'international neural network',
#  'computation neural network',
#  'network trained endtoend',
#  'rule neural network',
#  'hornik neural network',
#  'network based language',
#  'interpolation adaptive network',
#  'neural network decision',
#  'neural network artificial',
#  'cooperative competitive network',
#  'neural network router',
#  'presented neural network',
#  'network inference network',
#  'order derivative network',
#  'network simple minimizing',
#  'modeling neural network',
#  'combination neural network',
#  'structure bayesian network',
#  'network intrusion detection',
#  'neural network long',
#  'small neural network',
#  'convolutional network iclr',
#  'neural network different',
#  'path residual network',
#  'pursuit learning network',
#  'approximation neural network',
#  'framework backpropagation network',
#  'network pruning optimal',
#  'perceptual network computer',
#  'neural network allows',
#  'outbreak detection network',
#  'multilayered neural network',
#  'neural network relu',
#  'output layer network',
#  'network principle neural',
#  'bayesian network dbns',
#  'network first layer',
#  'neural network modelling',
#  'process neural network',
#  'derivative network pruning',
#  'invariant neural network',
#  'connection neural network',
#  'number unit network',
#  'network layer hidden',
#  'classification network output',
#  'neural network computer',
#  'network convolutional neural',
#  'social network page',
#  'network applied visual',
#  'output value network',
#  'parallel network learns',
#  'neural network data',
#  'deep feedforward network',
#  'neural network standard',
#  'general neural network',
#  'approach social network',
#  'social network proc',
#  'capability neural network',
#  'used training network',
#  'within neural network',
#  'neural network fixed',
#  'correlated network state',
#  'stochastic network design',
#  'network network trained',
#  'neural network special',
#  'network shared weight',
#  'parameterized neural network',
#  'performance network trained',
#  'infinite neural network',
#  'neural network convolutional',
#  'copula bayesian network',
#  'strongly correlated network',
#  'important size network',
#  'network nip tsochantaridis',
#  'neural network computational',
#  'network architecture described',
#  'network illustrated figure',
#  'network learning exponential',
#  'neural network hopfield',
#  'class bayesian network',
#  'modern neural network',
#  'neural network although',
#  'electronic neural network',
#  'bayesian network bounded',
#  'neural network nature',
#  'prediction neural network',
#  'network recurrent neural',
#  'another neural network',
#  'neural network tdnn',
#  'neural network performs',
#  'network used experiment',
#  'network learning rule',
#  'network trained data',
#  'network overfitting jmlr',
#  'trained network using',
#  'time step network',
#  'neural network constructed',
#  'network query selective',
#  'inference belief network',
#  'network single layer',
#  'real world network',
#  'several neural network',
#  'efficient neural network',
#  'convolutional network architecture',
#  'higher order network',
#  'sparsely connected network',
#  'network state neural',
#  'neural network find',
#  'neural network become',
#  'spiking neuron network',
#  'connectionist network query',
#  'network flow algorithm',
#  'multilayer perceptron network',
#  'accurate deep network',
#  'largescale neural network',
#  'deep symmetry network',
#  'convolutional network trained',
#  'margin markov network',
#  'network output layer',
#  'network learns recognize',
#  'network used model',
#  'feedback neural network',
#  'neural network represent',
#  'focused gamma network',
#  'network perform well',
#  'network trained training',
#  'neural network performance',
#  'feedforward network neural',
#  'kanade neural networkbased',
#  'network diffusion influence',
#  'fast neural network',
#  'network experimental result',
#  'lstm neural network',
#  'neural network autonomous',
#  'neural network composed',
#  'time neural network',
#  'stacked attention network',
#  'backpropagation network touretzky',
#  'basic network principle',
#  'image network computation',
#  'network feedforward network',
#  'equivalent multilayer network',
#  'work neural network',
#  'network convolutional layer',
#  'dynamic network surgery',
#  'domingo sumproduct network',
#  'neural network real',
#  'vehicle neural network',
#  'neural network consists',
#  'minimal network construction',
#  'network work well',
#  'network model using',
#  'feature network regularization',
#  'novel neural network',
#  'network whose output',
#  'network trained recognize',
#  'neural network second',
#  'network architecture isolated',
#  'neural network state',
#  'propagation neural network',
#  'network gaussian process',
#  'combined neural network',
#  'network weight matrix',
#  'neural network following',
#  'parallel network learn',
#  'neural network limited',
#  'using layer network',
#  'number parameter network',
#  'number node network',
#  'traditional neural network',
#  'statistical network analysis',
#  'hint neural network',
#  'siamese neural network',
#  'gradient neural network',
#  'network hidden neuron',
#  'generative neural network',
#  'bordes memory network',
#  'cycleconsistent adversarial network',
#  'neural network regularization',
#  'chemical reaction network',
#  'genetic regulatory network',
#  'network without hidden',
#  'neural network lecun',
#  'neural network computation',
#  'neural network anns',
#  'community detection network',
#  'like neural network',
#  'network model used',
#  'network proceeding ninth',
#  'girosi theory network',
#  'ladder network advance',
#  'neural network recognizer',
#  'inferring network diffusion',
#  'neural network three',
#  'network trained tested',
#  'network weight vector',
#  'network structure using',
#  'pulsed neural network',
#  'learning deep network',
#  'network touretzky editor',
#  'network learn pronounce',
#  'even though network',
#  'convolutional network efficient',
#  'data social network',
#  'vector neural network',
#  'largescale social network',
#  'autoregressive neural network',
#  'network bayesian network',
#  'network decision tree',
#  'neural network consider',
#  'using recurrent network',
#  'gradient deep network',
#  'neural network maximum',
#  'binarized neural network',
#  'layer layer network',
#  'neural network learned',
#  'neural network sparse',
#  'regularization network support',
#  'neural network longterm',
#  'markov network advance',
#  'network architecture hidden',
#  'network autonomous navigation',
#  'linsker basic network',
#  'neural network analog',
#  'hierarchical neural network',
#  'belief network using',
#  'neural network probability',
#  'network could learn',
#  'learning sumproduct network',
#  'neural network july',
#  'example social network',
#  'sensor network ieee',
#  'classifier neural network',
#  'single backpropagation network',
#  'standard backpropagation network',
#  'neural network feedback',
#  'diffusion network evolution',
#  'neural network studied',
#  'krause inferring network',
#  'spiegelhalter probabilistic network',
#  'probabilistic network expert',
#  'state neural network',
#  'object detection network',
#  'network map input',
#  'neural network note',
#  'process regression network',
#  'dynamic network model',
#  'rosenberg parallel network',
#  'multilayer network science',
#  'layer residual network',
#  'parsing anticipating network',
#  'neural network module',
#  'neural network activity',
#  'memoryaugmented neural network',
#  'training network trained',
#  'twolayer feedforward network',
#  'network receives input',
#  'structure markov network',
#  'logic network mlns',
#  'input pattern network',
#  'represented neural network',
#  'residual network resnet',
#  'social networking site',
#  'cumulative distribution network',
#  'recognition algorithm network',
#  'belief network model',
#  'initial condition network',
#  'feed another network',
#  'overview neural network',
#  'quantized neural network',
#  'network nip lecun',
#  'network journal complexity',
#  'neural network overview',
#  'recurrent network spiking',
#  'network must learn',
#  'network training data',
#  'network architecture learning',
#  'light response network',
#  'network touretzky advance',
#  'neural network character',
#  'dynamic probabilistic network',
#  'consider neural network',
#  'network grammatical inference',
#  'neural network npcomplete',
#  'adaptive network model',
#  'network comprehensive foundation',
#  'network model model',
#  'neural network small',
#  'neural network density',
#  'diffusion network icml',
#  'another network single',
#  'construct neural network',
#  'neural network usually',
#  'backprop neural network',
#  'network trained target',
#  'processing sensor network',
#  'neural network hardware',
#  'foundation adaptive network',
#  'neural network even',
#  'dynamic diffusion network',
#  'random network science',
#  'fergus deconvolutional network',
#  'bias minimal network',
#  'computational neural network',
#  'network proc page',
#  'internet network economics',
#  'combining neural network',
#  'edelman network learns',
#  'network ieee conference',
#  'network commonly used',
#  'scattering convolution network',
#  'performed neural network',
#  'poggio edelman network',
#  'belief network advance',
#  ...]

# %%
# Using inbuilt list to filter out alogithms
algo_list = ["expectation maximization algorithm","","","active learning problem","gradient descent algorithm","polynoial time algorithm","deep reinforcement learning","dehaene–changeux model","dynamic time warping","error-driven learning","evolutionary multimodal optimization","expectation–maximization algorithm","forward–backward algorithm","growing self-organizing map","hyper basis function network","nearest neighbor algorithm","principal component analysis","local outlier factor","logic learning machine","multiple kernel learning","out-of-bag error","non-negative matrix factorization","radial basis function network","support vector machine","logistic regression algorithm","linear regression algorithm","reinforcement learning","rule-based machine learning","stochastic gradient descent","k-nearest neighbour","temporal difference learning","Weighted majority algorithm"," algorithm kmeans clustering","collaborative filtering algorithm","recurrent neural network","reinforcement learning","decission tree classification","randon forest classifiers","voting classifier algorithm","convolution neural network","deep neural network","naive bayes algorithm","generative adversarial network","wake sleep algorithm"]

# %%
top_algos = list(set(tri).intersection(algo_list))

# %%
df.rename(columns={"neural information processing": "Algorithms", "8990": "Count"},inplace=True)

# %%
final_df = df[df["Algorithms"].isin(top_algos)]

# %%
final_df
# Out:
#                                Algorithms  Count
# 9                  support vector machine   2345
# 12               recurrent neural network   1489
# 15            stochastic gradient descent   1363
# 19           principal component analysis   1259
# 21                    deep neural network   1171
# 96         generative adversarial network    441
# 106            gradient descent algorithm    424
# 114              multiple kernel learning    404
# 208          temporal difference learning    274
# 217           deep reinforcement learning    263
# 1250   expectation maximization algorithm     91
# 1371           nearest neighbor algorithm     85
# 2162                 dynamic time warping     65
# 3974    collaborative filtering algorithm     46
# 6380              active learning problem     34
# 7640        logistic regression algorithm     31
# 22898         linear regression algorithm     16
# 47637          convolution neural network     10

# %%
clist = [(0, "red"), (0.125, "red"), (0.25, "orange"), (0.5, "green"), 
         (0.7, "green"), (0.75, "blue"), (1, "blue")]
rvb = mcolors.LinearSegmentedColormap.from_list("", clist)

algo = final_df["Algorithms"]
count = final_df["Count"]

N = len(algo)
x = np.arange(N).astype(float)
plt.figure(figsize=(24,14))
plt.bar(algo,count, color=rvb(x/N))
plt.xticks(algo, rotation=-85)
plt.show()

# %%
res1 = [k for k in res if 'learning' not in k]

# %%
res1
# Out:
# ['gradient descent algorithm',
#  'dynamic programming algorithm',
#  'belief propagation algorithm',
#  'message passing algorithm',
#  'polynomial time algorithm',
#  'coordinate descent algorithm',
#  'incomplete data algorithm',
#  'symposium discrete algorithm',
#  'approximate inference algorithm',
#  'monte carlo algorithm',
#  'running time algorithm',
#  'variational inference algorithm',
#  'algorithm advance neural',
#  'stochastic approximation algorithm',
#  'algorithm journal royal',
#  'spectral clustering algorithm',
#  'algorithm ieee transaction',
#  'algorithm neural network',
#  'data algorithm journal',
#  'algorithm neural computation',
#  'feature selection algorithm',
#  'algorithm described section',
#  'stochastic gradient algorithm',
#  'gibbs sampling algorithm',
#  'policy iteration algorithm',
#  'convergence rate algorithm',
#  'algorithm deep belief',
#  'expectation maximization algorithm',
#  'weighted majority algorithm',
#  'algorithm linear inverse',
#  'algorithm guaranteed converge',
#  'computationally efficient algorithm',
#  'iterative shrinkagethresholding algorithm',
#  'nearest neighbor algorithm',
#  'clustering analysis algorithm',
#  'international conference algorithmic',
#  'shrinkagethresholding algorithm linear',
#  'algorithm run time',
#  'algorithm approximate bayesian',
#  'policy gradient algorithm',
#  'discrete algorithm soda',
#  'differentially private algorithm',
#  'sparse coding algorithm',
#  'discrete algorithm page',
#  'section present algorithm',
#  'algorithm matrix completion',
#  'value iteration algorithm',
#  'algorithm performs well',
#  'least square algorithm',
#  'neural network algorithm',
#  'kmeans clustering algorithm',
#  'coordinate ascent algorithm',
#  'algorithm online convex',
#  'algorithm solve problem',
#  'convex optimization algorithm',
#  'computational complexity algorithm',
#  'algorithm work well',
#  'conditional gradient algorithm',
#  'algorithm connectionist reinforcement',
#  'algorithm journal machine',
#  'algorithm computationally efficient',
#  'algorithm take input',
#  'stochastic optimization algorithm',
#  'mirror descent algorithm',
#  'algorithm gradient descent',
#  'fixed point algorithm',
#  'gradientfollowing algorithm connectionist',
#  'statistical gradientfollowing algorithm',
#  'performance proposed algorithm',
#  'algorithm cambridge university',
#  'result show algorithm',
#  'algorithm regret bound',
#  'algorithm solving problem',
#  'regret bound algorithm',
#  'compare performance algorithm',
#  'algorithm figure show',
#  'proximal gradient algorithm',
#  'random structure algorithm',
#  'simple greedy algorithm',
#  'junction tree algorithm',
#  'algorithm stochastic gradient',
#  'show proposed algorithm',
#  'convergence property algorithm',
#  'algorithm technical report',
#  'algorithm take advantage',
#  'natural actorcritic algorithm',
#  'hinton view algorithm',
#  'algorithm ieee trans',
#  'alternating minimization algorithm',
#  'policy search algorithm',
#  'algorithm special case',
#  'algorithm arxiv preprint',
#  'algorithm section present',
#  'algorithm support vector',
#  'algorithm boltzmann machine',
#  'algorithm experimental result',
#  'algorithm justifies incremental',
#  'algorithm running time',
#  'view algorithm justifies',
#  'bayesian inference algorithm',
#  'efficient inference algorithm',
#  'conjugate gradient algorithm',
#  'propose efficient algorithm',
#  'regret algorithm online',
#  'logarithmic regret algorithm',
#  'proximal point algorithm',
#  'algorithm shown algorithm',
#  'mixture expert algorithm',
#  'algorithm independent component',
#  'algorithm shown figure',
#  'local search algorithm',
#  'matrix completion algorithm',
#  'algorithm presented section',
#  'algorithm perform well',
#  'value thresholding algorithm',
#  'algorithm latent dirichlet',
#  'time complexity algorithm',
#  'improved approximation algorithm',
#  'algorithm given algorithm',
#  'algorithm multiarmed bandit',
#  'algorithm summarized algorithm',
#  'inference algorithm based',
#  'algorithm described algorithm',
#  'probability least algorithm',
#  'efficient boosting algorithm',
#  'collaborative filtering algorithm',
#  'algorithm kmeans clustering',
#  'expert algorithm neural',
#  'algorithm also used',
#  'algorithm soda page',
#  'algorithm lower bound',
#  'paper present algorithm',
#  'performance different algorithm',
#  'efficient algorithm computing',
#  'thresholding algorithm matrix',
#  'dimensionality reduction algorithm',
#  'algorithm differentially private',
#  'algorithm proceeding international',
#  'algorithm nonnegative matrix',
#  'efficient algorithm solving',
#  'special case algorithm',
#  'time step algorithm',
#  'theory algorithm application',
#  'algorithm used solve',
#  'number iteration algorithm',
#  'family algorithm approximate',
#  'mean field algorithm',
#  'algorithm optimal margin',
#  'algorithm achieves regret',
#  'algorithm find optimal',
#  'minka family algorithm',
#  'exponentiated gradient algorithm',
#  'present efficient algorithm',
#  'objective function algorithm',
#  'training algorithm optimal',
#  'show performance algorithm',
#  'analysis algorithm advance',
#  'vapnik training algorithm',
#  'gradient ascent algorithm',
#  'algorithm supplementary material',
#  'combinatorial optimization algorithm',
#  'develop efficient algorithm',
#  'residual gradient algorithm',
#  'maximum margin algorithm',
#  'boosting algorithm combining',
#  'algorithm unsupervised neural',
#  'algorithm combining preference',
#  'clustering algorithm kmeans',
#  'algorithm much faster',
#  'design efficient algorithm',
#  'evaluate performance algorithm',
#  'lifted inference algorithm',
#  'efficient optimization algorithm',
#  'algorithmic implementation multiclass',
#  'algorithm constructing approximate',
#  'neal wakesleep algorithm',
#  'boosting algorithm using',
#  'procedure summarized algorithm',
#  'efficient algorithm solve',
#  'lower bound algorithm',
#  'cutting plane algorithm',
#  'algorithm presented algorithm',
#  'algorithm information computation',
#  'propagation algorithm ieee',
#  'computational cost algorithm',
#  'linearthreshold algorithm machine',
#  'paper propose algorithm',
#  'algorithm partially observable',
#  'wakesleep algorithm unsupervised',
#  'improved boosting algorithm',
#  'sample complexity algorithm',
#  'abound linearthreshold algorithm',
#  'section describe algorithm',
#  'model inference algorithm',
#  'efficient algorithm online',
#  'multiarmed bandit algorithm',
#  'majority algorithm information',
#  'algorithmic game theory',
#  'best known algorithm',
#  'contextual bandit algorithm',
#  'algorithm siam journal',
#  'forwardbackward greedy algorithm',
#  'simple efficient algorithm',
#  'algorithm related work',
#  'using perceptron algorithm',
#  'abstract present algorithm',
#  'variational algorithm approximate',
#  'algorithm algorithm algorithm',
#  'time algorithm nearoptimal',
#  'singer algorithmic implementation',
#  'present novel algorithm',
#  'algorithm previous section',
#  'algorithm approximate inference',
#  'algorithm international conference',
#  'algorithm online decision',
#  'image segmentation algorithm',
#  'algorithm continually running',
#  'algorithm nearoptimal reinforcement',
#  'dueling bandit algorithm',
#  'algorithm parameter estimation',
#  'algorithm using confidencerated',
#  'seung algorithm nonnegative',
#  'randomness probabilistic algorithm',
#  'algorithm linear programming',
#  'maximum likelihood algorithm',
#  'probabilistic algorithm constructing',
#  'compare proposed algorithm',
#  'subspace clustering algorithm',
#  'summarized algorithm algorithm',
#  'algorithm closely related',
#  'algorithm provable guarantee',
#  'computer vision algorithm',
#  'give efficient algorithm',
#  'carlo mcmc algorithm',
#  'algorithm large scale',
#  'data algorithm royal',
#  'effectiveness proposed algorithm',
#  'figure show algorithm',
#  'graph sumproduct algorithm',
#  'algorithm main result',
#  'hierarchical clustering algorithm',
#  'sparse recovery algorithm',
#  'algorithm mixture factor',
#  'algorithm quadratic programming',
#  'sequence generated algorithm',
#  'theoretical guarantee algorithm',
#  'algorithm page society',
#  'algorithm maximizing submodular',
#  'using greedy algorithm',
#  'algorithm maximum likelihood',
#  'beal variational algorithm',
#  'algorithm data set',
#  'algorithm probability least',
#  'logistic regression algorithm',
#  'hinton algorithm mixture',
#  'algorithm submodular function',
#  'algorithm implemented matlab',
#  'clustering algorithm based',
#  'feature extraction algorithm',
#  'spectral algorithm latent',
#  'propose novel algorithm',
#  'performance guarantee algorithm',
#  'first step algorithm',
#  'algorithm synthetic data',
#  'vempala efficient algorithm',
#  'component analysis algorithm',
#  'exact inference algorithm',
#  'selective sampling algorithm',
#  'algorithm used find',
#  'algorithm convex optimization',
#  'propose algorithm called',
#  'wolfe algorithm quadratic',
#  'algorithm inverse reinforcement',
#  'algorithm section describe',
#  'algorithm next section',
#  'sumproduct algorithm ieee',
#  'matching pursuit algorithm',
#  'algorithm proceeds follows',
#  'algorithm able learn',
#  'efficient algorithm based',
#  'algorithm blind signal',
#  'fixedpoint algorithm independent',
#  'algorithm theoretical guarantee',
#  'supplementary material algorithm',
#  'simulated annealing algorithm',
#  'crammer singer algorithmic',
#  'algorithm scale linearly',
#  'algorithm gaussian mixture',
#  'algorithm scale well',
#  'thompson sampling algorithm',
#  'analysis algorithm nip',
#  'algorithm real data',
#  'high probability algorithm',
#  'algorithm compressed sensing',
#  'algorithm widely used',
#  'optimization problem algorithm',
#  'loss function algorithm',
#  'algorithm graphical model',
#  'residual algorithm reinforcement',
#  'parameter estimation algorithm',
#  'natural gradient algorithm',
#  'algorithm mixture model',
#  'regret minimizing algorithm',
#  'experiment show algorithm',
#  'zhang spectral algorithm',
#  'algorithm strongly convex',
#  'algorithm recently proposed',
#  'algorithm nuclear norm',
#  'algorithm based convex',
#  'baird residual algorithm',
#  'algorithm nip page',
#  'linear time algorithm',
#  'algorithm online algorithm',
#  'spanning tree algorithm',
#  'given algorithm algorithm',
#  'algorithm achieves optimal',
#  'algorithm work follows',
#  'online boosting algorithm',
#  'decision tree algorithm',
#  'anomaly detection algorithm',
#  'linear programming algorithm',
#  'algorithm approximate nearest',
#  'approximation algorithm kmeans',
#  'algorithm described previous',
#  'approximation algorithm maximum',
#  'using backpropagation algorithm',
#  'importance sampling algorithm',
#  'algorithm guaranteed find',
#  'algorithm stochastic optimization',
#  'algorithm converges optimal',
#  'russell algorithm inverse',
#  'update rule algorithm',
#  'support vector algorithm',
#  'algorithm subset selection',
#  'derive efficient algorithm',
#  'algorithm presented paper',
#  'conic duality algorithm',
#  'described algorithm algorithm',
#  'projected gradient algorithm',
#  'algorithm upper bound',
#  'query committee algorithm',
#  'frank wolfe algorithm',
#  'algorithm significantly outperforms',
#  'time approximation algorithm',
#  'experiment perceptron algorithm',
#  'adaptive sampling algorithm',
#  'efficient algorithm empirical',
#  'source separation algorithm',
#  'ghahramani hinton algorithm',
#  'convergence analysis algorithm',
#  'efficient algorithm exist',
#  'technique rounding algorithm',
#  'algorithm time complexity',
#  'analysis minimization algorithm',
#  'domain adaptation algorithm',
#  'show algorithm outperforms',
#  'algorithm section show',
#  'confidence bound algorithm',
#  'dual averaging algorithm',
#  'standard backpropagation algorithm',
#  'many algorithm proposed',
#  'conclusion presented algorithm',
#  'factor approximation algorithm',
#  'algorithm spectral clustering',
#  'clustering algorithm using',
#  'exponential weight algorithm',
#  'section show algorithm',
#  'several algorithm proposed',
#  'algorithm belief propagation',
#  'theory algorithm cambridge',
#  'empirical performance algorithm',
#  'proximal newton algorithm',
#  'algorithm sparse coding',
#  'algorithm proposed algorithm',
#  'errorrates using algorithm',
#  'demonstrate effectiveness algorithm',
#  'bound regret algorithm',
#  'tensor decomposition algorithm',
#  'theoretical analysis algorithm',
#  'algorithm start initial',
#  'algorithm binary classification',
#  'also show algorithm',
#  'minimax optimal algorithm',
#  'graph partitioning algorithm',
#  'algorithm following theorem',
#  'algorithm convergence rate',
#  'gradientbased optimization algorithm',
#  'performance various algorithm',
#  'show algorithm converges',
#  'step size algorithm',
#  'algorithm take time',
#  'algorithm thompson sampling',
#  'algorithm perform better',
#  'detailed description algorithm',
#  'algorithm easy implement',
#  'algorithm used experiment',
#  'algorithm energy minimization',
#  'expectation propagation algorithm',
#  'using genetic algorithm',
#  'bound optimal algorithm',
#  'obtain efficient algorithm',
#  'polynomialtime approximation algorithm',
#  'algorithm proof theorem',
#  'best performing algorithm',
#  'lead efficient algorithm',
#  'greedy algorithm sparse',
#  'algorithm also show',
#  'algorithm objective function',
#  'measure performance algorithm',
#  'proposed algorithm outperforms',
#  'idea behind algorithm',
#  'algorithm order magnitude',
#  'shown algorithm algorithm',
#  'algorithm described figure',
#  'algorithm step size',
#  'algorithm given figure',
#  'algorithm described above',
#  'underlying clustering algorithm',
#  'evaluate proposed algorithm',
#  'probabilistic inference algorithm',
#  'algorithm nearest neighbor',
#  'zhang epochgreedy algorithm',
#  'high dimensional algorithm',
#  'approximation guarantee algorithm',
#  'algorithm minimizing submodular',
#  'algorithm greedy algorithm',
#  'model selection algorithm',
#  'algorithm principal component',
#  'algorithm maximum satisfiability',
#  'algorithm described paper',
#  'generalized hebbian algorithm',
#  'show algorithm achieves',
#  'algorithm given sample',
#  'random struct algorithm',
#  'knearest neighbor algorithm',
#  'performance three algorithm',
#  'double greedy algorithm',
#  'algorithm empirical result',
#  'algorithm variational inference',
#  'variational bayes algorithm',
#  'algorithm computational complexity',
#  'expected regret algorithm',
#  'causal discovery algorithm',
#  'algorithm information theory',
#  'algorithm empirical study',
#  'inference algorithm latent',
#  'using kmeans algorithm',
#  'algorithm implemented using',
#  'algorithm statistical optimization',
#  'efficient approximation algorithm',
#  'greedy algorithm find',
#  'algorithm fixed point',
#  'intuition behind algorithm',
#  'good algorithmic result',
#  'kalman filter algorithm',
#  'algorithm used learn',
#  'algorithm topic modeling',
#  'algorithm future work',
#  'algorithmic result sparse',
#  'online passiveaggressive algorithm',
#  'network training algorithm',
#  'show algorithm performs',
#  'back propagation algorithm',
#  'committee algorithm machine',
#  'efficient online algorithm',
#  'algorithm temporal difference',
#  'flow theory algorithm',
#  'inference algorithm model',
#  'algorithm also known',
#  'even though algorithm',
#  'algorithm converges local',
#  'spike sorting algorithm',
#  'algorithm royal statistical',
#  'greed good algorithmic',
#  'matrix factorization algorithm',
#  'algorithm finding best',
#  'algorithm foundation trend',
#  'every iteration algorithm',
#  'binary classification algorithm',
#  'using proposed algorithm',
#  'large margin algorithm',
#  'algorithm based upon',
#  'algorithm also applied',
#  'experiment boosting algorithm',
#  'theory efficient algorithm',
#  'algorithm similar algorithm',
#  'algorithm sample complexity',
#  'boosting algorithm gradient',
#  'efficient algorithm bandit',
#  'algorithm best knowledge',
#  'linear leastsquares algorithm',
#  'algorithm address problem',
#  'hashing algorithm approximate',
#  'theorem show algorithm',
#  'shown figure algorithm',
#  'tree search algorithm',
#  'temporal difference algorithm',
#  'theorem suppose algorithm',
#  'steepest descent algorithm',
#  'anytime algorithm pomdps',
#  'next section algorithm',
#  'nearoptimal hashing algorithm',
#  'efficient algorithm compute',
#  'relative error csspalgorithm',
#  'widely used algorithm',
#  'model recognition algorithm',
#  'fast fixedpoint algorithm',
#  'algorithm could used',
#  'algorithm contextual bandit',
#  'algorithm training data',
#  'convergence result algorithm',
#  'algorithm achieves best',
#  'algorithm minimize bethe',
#  'algorithm collaborative filtering',
#  'algorithm whose regret',
#  'provide efficient algorithm',
#  'recently proposed algorithm',
#  'algorithm feature selection',
#  'algorithm applied statistic',
#  'algorithm annals statistic',
#  'binary search algorithm',
#  'introduction algorithm press',
#  'approximation algorithm kmedian',
#  'inner loop algorithm',
#  'adaptive algorithm based',
#  'segmentation algorithm measuring',
#  'mcmc inference algorithm',
#  'primaldual algorithm convex',
#  'algorithm stochastic approximation',
#  'optimization algorithm used',
#  'algorithm measuring ecological',
#  'firstorder primaldual algorithm',
#  'algorithm easily extended',
#  'iterative thresholding algorithm',
#  'algorithm discussed section',
#  'algorithm make prediction',
#  'algorithm neural information',
#  'mahoney randomized algorithm',
#  'using forwardbackward algorithm',
#  'algorithm coordinate descent',
#  'first order algorithm',
#  'roweis algorithm spca',
#  'algorithm hierarchical clustering',
#  'stopping criterion algorithm',
#  'forward greedy algorithm',
#  'main idea algorithm',
#  'using algorithm applied',
#  'convergence guarantee algorithm',
#  'secondorder perceptron algorithm',
#  'evaluating segmentation algorithm',
#  'community detection algorithm',
#  'leastsquares algorithm temporal',
#  'algorithm even though',
#  'boosting tree algorithm',
#  'using algorithm described',
#  'algorithm based idea',
#  'problem proposed algorithm',
#  'algorithm used train',
#  'algorithm section provide',
#  'algorithm exact inference',
#  'greedy algorithm achieves',
#  'perceptron algorithm machine',
#  'algorithm algorithm first',
#  'asymptotically optimal algorithm',
#  'outperforms existing algorithm',
#  'algorithm need know',
#  'rate convergence algorithm',
#  'algorithm section discus',
#  'second order algorithm',
#  'figure performance algorithm',
#  'randomized kaczmarz algorithm',
#  'algorithm find solution',
#  'comparison mincutmaxflow algorithm',
#  'posterior inference algorithm',
#  'approximation algorithm problem',
#  'mincutmaxflow algorithm energy',
#  'offline greedy algorithm',
#  'algorithm factor analysis',
#  'competitive ratio algorithm',
#  'algorithm successfully applied',
#  'multiplicative weight algorithm',
#  'using expectationmaximization algorithm',
#  'algorithm theoretical analysis',
#  'algorithm make mistake',
#  'algorithm training neural',
#  'propagation algorithm approximate',
#  'pseudocode given algorithm',
#  'algorithm approximation guarantee',
#  'different clustering algorithm',
#  'branch bound algorithm',
#  'label complexity algorithm',
#  'algorithm first algorithm',
#  'proposed algorithm based',
#  'randomized algorithm matrix',
#  'algorithm mathematical programming',
#  'algorithm following property',
#  'graph clustering algorithm',
#  'coordinate minimization algorithm',
#  'efficient sampling algorithm',
#  'best knowledge algorithm',
#  'iteration anytime algorithm',
#  'algorithm guarantee regret',
#  'finkel algorithm finding',
#  'algorithm page siam',
#  'greedy algorithm submodular',
#  'algorithm illustrated figure',
#  'optimization algorithm technique',
#  'using standard algorithm',
#  'apply proposed algorithm',
#  'algorithm learn parameter',
#  'algorithm linear function',
#  'output algorithm satisfies',
#  'algorithm section introduce',
#  'inference algorithm proposed',
#  'using viterbi algorithm',
#  'proposed algorithm also',
#  'procedure described algorithm',
#  'algorithm worst case',
#  'data set algorithm',
#  'prove convergence algorithm',
#  'algorithm graph partitioning',
#  'efficient algorithm finding',
#  'section introduce algorithm',
#  'call resulting algorithm',
#  'proposed efficient algorithm',
#  'efficient algorithm problem',
#  'algorithm compare favorably',
#  'following algorithm algorithm',
#  'algorithm computational cost',
#  'algorithm least square',
#  'regularized leastsquares algorithm',
#  'algorithm iterative algorithm',
#  'algorithm take account',
#  'standard clustering algorithm',
#  'algorithm also provide',
#  'firstorder optimization algorithm',
#  'algorithm solve optimization',
#  'sparse sampling algorithm',
#  'algorithm finding optimal',
#  'upper bound algorithm',
#  'algorithm compare performance',
#  'algorithm synthetic real',
#  'greedy search algorithm',
#  'algorithm solves problem',
#  'much faster algorithm',
#  'provably optimal algorithm',
#  'optimal algorithm crowdsourcing',
#  'algorithm high probability',
#  'algorithm proposed solve',
#  'statistical guarantee algorithm',
#  'training data algorithm',
#  'algorithm converges global',
#  'polygonal line algorithm',
#  'algorithm matrix data',
#  'outperforms stateoftheart algorithm',
#  'linear bandit algorithm',
#  'statistical query algorithm',
#  'algorithm linear stochastic',
#  'greedy algorithm algorithm',
#  'algorithm combinatorial optimization',
#  'optimization algorithm based',
#  'data point algorithm',
#  'algorithm bound constrained',
#  'algorithm theoretical result',
#  'variational bayesian algorithm',
#  'algorithm keep track',
#  'algorithm data structure',
#  'genetic algorithm search',
#  'distributed inference algorithm',
#  'inference algorithm used',
#  'algorithm blind separation',
#  'algorithm dueling bandit',
#  'knowledge first algorithm',
#  'algorithm logistic regression',
#  'algorithm able find',
#  'algorithm achieve optimal',
#  'analysis algorithm application',
#  'dimension reduction algorithm',
#  'algorithm recurrent neural',
#  'algorithm able recover',
#  'algorithm well known',
#  'algorithm always converges',
#  'efficiency proposed algorithm',
#  'show resulting algorithm',
#  'maximum flow algorithm',
#  'improved algorithm linear',
#  'algorithm policy evaluation',
#  'algorithm based variational',
#  'algorithm loss function',
#  'boyd proximal algorithm',
#  'optimal solution algorithm',
#  'divide conquer algorithm',
#  'algorithm pattern recognition',
#  'performance algorithm using',
#  'algorithm mach learn',
#  'algorithm based neuromimetic',
#  'computation time algorithm',
#  'algorithm loopy belief',
#  'line search algorithm',
#  'algorithm find best',
#  'algorithm siam review',
#  'optimal algorithm stochastic',
#  'algorithm real world',
#  'bayesian optimization algorithm',
#  'test performance algorithm',
#  'spectral regularization algorithm',
#  'algorithm proposed paper',
#  'algorithm estimate parameter',
#  'algorithm applied problem',
#  'algorithm show algorithm',
#  'optimal algorithm online',
#  'algorithm isotonic regression',
#  'propose iterative algorithm',
#  'markov chain algorithm',
#  'greedy algorithm maximizing',
#  'optimization algorithm section',
#  'simple effective algorithm',
#  'algorithm bandit linear',
#  'result proposed algorithm',
#  'inference algorithm described',
#  'algorithm arbitrary graph',
#  'asynchronous parallel algorithm',
#  'passing algorithm lprelaxations',
#  'lloyd kmeans algorithm',
#  'performance algorithm compared',
#  'algorithm learn model',
#  'show greedy algorithm',
#  'descent algorithm solve',
#  'based algorithm reinforcement',
#  'rounding algorithm stoc',
#  'demonstrate proposed algorithm',
#  'algorithm efficiently compute',
#  'pointbased pomdp algorithm',
#  'algorithm significantly better',
#  'communicationefficient algorithm statistical',
#  'algorithm ising model',
#  'regularization based algorithm',
#  'using iterative algorithm',
#  'algorithm compute optimal',
#  'dark efficient algorithm',
#  'algorithm used compute',
#  'part adaptive algorithm',
#  'algorithm proc icml',
#  'algorithm main idea',
#  'algorithm would require',
#  'linear regression algorithm',
#  'bound optimization algorithm',
#  'network flow algorithm',
#  'algorithm convex problem',
#  'trained using algorithm',
#  'regularized boosting algorithm',
#  'closely related algorithm',
#  'optimization algorithm matrix',
#  'algorithm section section',
#  'algorithm update weight',
#  'clustering algorithm used',
#  'algorithm data point',
#  'algorithm section propose',
#  'algorithm produce good',
#  'result applying algorithm',
#  'figure comparison algorithm',
#  'algorithm topic model',
#  'distributed optimization algorithm',
#  'density estimation algorithm',
#  'approximation algorithm machine',
#  'algorithm submodular maximization',
#  'backpropagation algorithm used',
#  'procedure given algorithm',
#  'algorithm clustering data',
#  'algorithm theory application',
#  'algorithm solving linear',
#  'fast greedy algorithm',
#  'presented algorithm algorithm',
#  'algorithm time step',
#  'programming algorithm neural',
#  'algorithm achieves approximation',
#  'algorithm computationally expensive',
#  'algorithm run polynomial',
#  'iterative algorithm solving',
#  'algorithm need compute',
#  'general purpose algorithm',
#  'section propose algorithm',
#  'computed using algorithm',
#  'algorithm architecture application',
#  'algorithm performance guarantee',
#  'optimization algorithm complexity',
#  'proximal algorithm foundation',
#  'algorithm iteratively update',
#  'phase retrieval algorithm',
#  'algorithm achieve regret',
#  'epochgreedy algorithm multiarmed',
#  'design analysis algorithm',
#  'many existing algorithm',
#  'girosi regularization algorithm',
#  'compared performance algorithm',
#  'using algorithm journal',
#  'algorithm implemented efficiently',
#  'fast simple algorithm',
#  'algorithmic point view',
#  'bentley finkel algorithm',
#  'model greedy algorithm',
#  'algorithm upper bounded',
#  'likelihood algorithm siam',
#  'algorithm variational bayesian',
#  'presented efficient algorithm',
#  'multiplicative update algorithm',
#  'section describes algorithm',
#  'agglomerative clustering algorithm',
#  'algorithm multiclass problem',
#  'nonconvex optimization algorithm',
#  'greedy algorithm subset',
#  'global optimization algorithm',
#  'noise removal algorithm',
#  'algorithm converge optimal',
#  'cost function algorithm',
#  'first iteration algorithm',
#  'algorithm number iteration',
#  'present algorithm solving',
#  'multiple tree algorithm',
#  'algorithm input data',
#  'paper develop algorithm',
#  'algorithm experiment section',
#  'algorithm would like',
#  'optimization theory algorithm',
#  'algorithm described detail',
#  'evaluated performance algorithm',
#  'online algorithm maximizing',
#  'algorithm based stochastic',
#  'algorithm within framework',
#  'method summarized algorithm',
#  'algorithm commonly used',
#  'mistake made algorithm',
#  'propose algorithm based',
#  'frean boosting algorithm',
#  'algorithm markov chain',
#  'well known algorithm',
#  'global convergence algorithm',
#  'high level algorithm',
#  'algorithm could also',
#  'algorithm hidden markov',
#  'tsitsiklis actorcritic algorithm',
#  'algorithm journal computer',
#  'algorithm consists step',
#  'algorithm population samplebased',
#  'regret minimization algorithm',
#  'algorithm classification problem',
#  'step step algorithm',
#  'backpropagation algorithm rumelhart',
#  'gradient algorithm solve',
#  'algorithm freund schapire',
#  'algorithm exponential convergence',
#  'convergence proof algorithm',
#  'single linkage algorithm',
#  'hard clustering algorithm',
#  'algorithm convergence analysis',
#  'ksvd algorithm designing',
#  'algorithm approximate estimation',
#  'algorithm consistently outperforms',
#  'motion segmentation algorithm',
#  'klucb algorithm bounded',
#  'solution returned algorithm',
#  'smith geometry algorithm',
#  'algorithm given point',
#  'theoretical property algorithm',
#  'show result algorithm',
#  'proposed algorithm achieves',
#  'hard thresholding algorithm',
#  'performance online algorithm',
#  'cumulative loss algorithm',
#  'perceptron algorithm proceeding',
#  'column generation algorithm',
#  'constrained gradient algorithm',
#  'algorithm bounded stochastic',
#  'efficient training algorithm',
#  'empirically evaluate algorithm',
#  'algorithm designing overcomplete',
#  'algorithm online optimization',
#  'efficient algorithm developed',
#  'proposed algorithm called',
#  'proposed algorithm section',
#  'algorithm handwritten digit',
#  'algorithm posterior inference',
#  'algorithm numerical experiment',
#  'interior point algorithm',
#  'algorithm application neural',
#  'approximation algorithm ising',
#  'carlo algorithm matrix',
#  'algorithm mean field',
#  'algorithm used estimate',
#  'algorithm previous work',
#  'algorithm expected regret',
#  'algorithm orthogonality constraint',
#  'algorithm iteration algorithm',
#  'algorithm update parameter',
#  'first phase algorithm',
#  'structured prediction algorithm',
#  'weight update algorithm',
#  'algorithm present algorithm',
#  'algorithm based following',
#  'algorithm given access',
#  'inference algorithm scale',
#  'algorithm sparse recovery',
#  'demonstrate performance algorithm',
#  'algorithm summarized follows',
#  'forecasting using algorithm',
#  'algorithm solving optimization',
#  'column selection algorithm',
#  'margin classification algorithm',
#  'barrier optimal algorithm',
#  'algorithm section give',
#  'system using algorithm',
#  'kakade spectral algorithm',
#  'standard greedy algorithm',
#  'algorithm stochastic stronglyconvex',
#  'recognition algorithm network',
#  'algorithm specifically designed',
#  'fast approximation algorithm',
#  'stein introduction algorithm',
#  'algorithm proceeding conference',
#  'removal algorithm physica',
#  'geometry algorithm orthogonality',
#  'experiment demonstrate algorithm',
#  'guarantee algorithm population',
#  'second phase algorithm',
#  'algorithm used training',
#  'bregman iterative algorithm',
#  'performance greedy algorithm',
#  'approximation algorithm application',
#  'algorithm wide range',
#  'bruckstein ksvd algorithm',
#  'survey propagation algorithm',
#  'algorithm optimization problem',
#  'algorithm value iteration',
#  'present algorithm called',
#  'algorithm total number',
#  'clustering algorithm applied',
#  'margin clustering algorithm',
#  'exists efficient algorithm',
#  'algorithm much efficient',
#  'label aggregation algorithm',
#  'online version algorithm',
#  'algorithm proc conf',
#  'current stateoftheart algorithm',
#  'several existing algorithm',
#  'object proposal algorithm',
#  'wainwright communicationefficient algorithm',
#  'isotron algorithm highdimensional',
#  'shrinkage thresholding algorithm',
#  'robust fixedpoint algorithm',
#  'paper describes algorithm',
#  'greedy approximation algorithm',
#  'gradient algorithm converges',
#  'algorithm maximum entropy',
#  'pairwise ranking algorithm',
#  'proposed algorithm achieve',
#  'random feature algorithm',
#  'algorithm markov decision',
#  'xiao optimal algorithm',
#  'conference genetic algorithm',
#  'algorithm well suited',
#  'algorithm approximately solving',
#  'method meta algorithm',
#  'golovin online algorithm',
#  'algorithm dempster laird',
#  'editor algorithmic game',
#  'neural algorithm sparse',
#  'proposed algorithm us',
#  'algorithm statistically consistent',
#  'robustness pnorm algorithm',
#  'subset selection algorithm',
#  'algorithm nonconvex optimization',
#  'algorithm following hold',
#  'modified version algorithm',
#  'algorithm simultaneous sparse',
#  'mcmc sampling algorithm',
#  'particle filtering algorithm',
#  'time taken algorithm',
#  'complexity proposed algorithm',
#  'efficient distributed algorithm',
#  'sampling based algorithm',
#  'convergence behavior algorithm',
#  'algorithm probability distribution',
#  'algorithm different value',
#  'algorithm find local',
#  'algorithm distance metric',
#  'algorithm finally section',
#  'compared existing algorithm',
#  'algorithm finding lowrank',
#  'many clustering algorithm',
#  'batch online algorithm',
#  'algorithm matrix manifold',
#  'algorithm majority information',
#  'contrastive divergence algorithm',
#  'algorithm start empty',
#  'sequence produced algorithm',
#  'risk minimization algorithm',
#  'curvature optimal algorithm',
#  'gradient algorithm nuclear',
#  'limited memory algorithm',
#  'algorithm foundation computational',
#  ...]

# %%
top_algos
# Out:
# ['support vector machine',
#  'stochastic gradient descent',
#  'gradient descent algorithm',
#  'linear regression algorithm',
#  'convolution neural network',
#  'collaborative filtering algorithm',
#  'expectation maximization algorithm',
#  'temporal difference learning',
#  'generative adversarial network',
#  'logistic regression algorithm',
#  'active learning problem',
#  'recurrent neural network',
#  'deep reinforcement learning',
#  'principal component analysis',
#  'deep neural network',
#  'nearest neighbor algorithm',
#  'dynamic time warping',
#  'multiple kernel learning']

# %%
countVectorizer = CountVectorizer(inputCol="trigrams", outputCol="features", vocabSize = 100000, minDF=2)
cv_model = countVectorizer.fit(trigramDataFrame)
result = cv_model.transform(trigramDataFrame)

# %%
result.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# |                text|               words|             bigrams|            trigrams|            features|
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# |selforganization ...|[selforganization...|[selforganization...|[selforganization...|(100000,[150,398,...|
# |mean field theory...|[mean, field, the...|[mean field, fiel...|[mean field theor...|(100000,[47,50,11...|
# |storing covarianc...|[storing, covaria...|[storing covarian...|[storing covarian...|(100000,[87,195,3...|
# |bayesian query co...|[bayesian, query,...|[bayesian query, ...|[bayesian query c...|(100000,[34,35,39...|
# |neural network en...|[neural, network,...|[neural network, ...|[neural network e...|(100000,[0,1,2,31...|
# |sing neural insta...|[sing, neural, in...|[sing neural, neu...|[sing neural inst...|(100000,[0,1,2,8,...|
# |plasticitymediate...|[plasticitymediat...|[plasticitymediat...|[plasticitymediat...|(100000,[0,1,2,28...|
# |iceg morphology c...|[iceg, morphology...|[iceg morphology,...|[iceg morphology ...|(100000,[80,129,1...|
# |realtime control ...|[realtime, contro...|[realtime control...|[realtime control...|(100000,[12,50,69...|
# |realtime control ...|[realtime, contro...|[realtime control...|[realtime control...|(100000,[12,50,69...|
# |learning play gam...|[learning, play, ...|[learning play, p...|[learning play ga...|(100000,[0,1,2,4,...|
# |multidimensional ...|[multidimensional...|[multidimensional...|[multidimensional...|(100000,[9,32,75,...|
# |experimental comp...|[experimental, co...|[experimental com...|[experimental com...|(100000,[13,43,49...|
# |training multilay...|[training, multil...|[training multila...|[training multila...|(100000,[43,51,79...|
# |interference lear...|[interference, le...|[interference lea...|[interference lea...|(100000,[57,808,2...|
# |active learning s...|[active, learning...|[active learning,...|[active learning ...|(100000,[0,1,2,28...|
# |rapid graphbased ...|[rapid, graphbase...|[rapid graphbased...|[rapid graphbased...|(100000,[0,2,129,...|
# |ocular dominance ...|[ocular, dominanc...|[ocular dominance...|[ocular dominance...|(100000,[12,30,49...|
# |associative decor...|[associative, dec...|[associative deco...|[associative deco...|(100000,[0,1,2,89...|
# |connectionist tec...|[connectionist, t...|[connectionist te...|[connectionist te...|(100000,[0,1,2,14...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
idf = IDF(inputCol="features", outputCol="IDFfeatures")
idfModel = idf.fit(result)
rescaledData = idfModel.transform(result)

# %% [markdown]
# #### Results

# %%
rescaledData.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |                text|               words|             bigrams|            trigrams|            features|         IDFfeatures|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |selforganization ...|[selforganization...|[selforganization...|[selforganization...|(100000,[150,398,...|(100000,[150,398,...|
# |mean field theory...|[mean, field, the...|[mean field, fiel...|[mean field theor...|(100000,[47,50,11...|(100000,[47,50,11...|
# |storing covarianc...|[storing, covaria...|[storing covarian...|[storing covarian...|(100000,[87,195,3...|(100000,[87,195,3...|
# |bayesian query co...|[bayesian, query,...|[bayesian query, ...|[bayesian query c...|(100000,[34,35,39...|(100000,[34,35,39...|
# |neural network en...|[neural, network,...|[neural network, ...|[neural network e...|(100000,[0,1,2,31...|(100000,[0,1,2,31...|
# |sing neural insta...|[sing, neural, in...|[sing neural, neu...|[sing neural inst...|(100000,[0,1,2,8,...|(100000,[0,1,2,8,...|
# |plasticitymediate...|[plasticitymediat...|[plasticitymediat...|[plasticitymediat...|(100000,[0,1,2,28...|(100000,[0,1,2,28...|
# |iceg morphology c...|[iceg, morphology...|[iceg morphology,...|[iceg morphology ...|(100000,[80,129,1...|(100000,[80,129,1...|
# |realtime control ...|[realtime, contro...|[realtime control...|[realtime control...|(100000,[12,50,69...|(100000,[12,50,69...|
# |realtime control ...|[realtime, contro...|[realtime control...|[realtime control...|(100000,[12,50,69...|(100000,[12,50,69...|
# |learning play gam...|[learning, play, ...|[learning play, p...|[learning play ga...|(100000,[0,1,2,4,...|(100000,[0,1,2,4,...|
# |multidimensional ...|[multidimensional...|[multidimensional...|[multidimensional...|(100000,[9,32,75,...|(100000,[9,32,75,...|
# |experimental comp...|[experimental, co...|[experimental com...|[experimental com...|(100000,[13,43,49...|(100000,[13,43,49...|
# |training multilay...|[training, multil...|[training multila...|[training multila...|(100000,[43,51,79...|(100000,[43,51,79...|
# |interference lear...|[interference, le...|[interference lea...|[interference lea...|(100000,[57,808,2...|(100000,[57,808,2...|
# |active learning s...|[active, learning...|[active learning,...|[active learning ...|(100000,[0,1,2,28...|(100000,[0,1,2,28...|
# |rapid graphbased ...|[rapid, graphbase...|[rapid graphbased...|[rapid graphbased...|(100000,[0,2,129,...|(100000,[0,2,129,...|
# |ocular dominance ...|[ocular, dominanc...|[ocular dominance...|[ocular dominance...|(100000,[12,30,49...|(100000,[12,30,49...|
# |associative decor...|[associative, dec...|[associative deco...|[associative deco...|(100000,[0,1,2,89...|(100000,[0,1,2,89...|
# |connectionist tec...|[connectionist, t...|[connectionist te...|[connectionist te...|(100000,[0,1,2,14...|(100000,[0,1,2,14...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# #### Trying out LDA model for clustering data (Future scope)

# %%
corpus = result.select("text", "features").rdd.map(lambda z: [z[0],Vectors.fromML(z[1])]).cache()

# Cluster the documents into three topics using LDA
ldaModel = LDA.train(corpus, k=3,maxIterations=100,optimizer='online')
topics = ldaModel.topicsMatrix()
vocabArray = model.vocabulary

wordNumbers = 15  # number of words per topic
topicIndices = sc.parallelize(ldaModel.describeTopics(maxTermsPerTopic = wordNumbers))

def topic_render(topic):  # specify vector id of words to actual words
    terms = topic[0]
    result = []
    for i in range(wordNumbers):
        term = vocabArray[terms[i]]
        result.append(term)
    return result

topics_final = topicIndices.map(lambda topic: topic_render(topic)).collect()

for topic in range(len(topics_final)):
    print ("Topic" + str(topic) + ":")
    for term in topics_final[topic]:
        print (term)
    print ('\n')

# %%
counts = result.select('features').collect()

# %%
len(counts)
# Out:
# 7239

# %%
voc = cv_model.vocabulary

# %%
len(voc)
# Out:
# 100000

# %%
final_words = dict(zip(cv_model.vocabulary, counts[0]['features'].values))

# %%
len(final_words)
# Out:
# 37
